# %% [markdown]
# # Part 1 -- Setup and Collection of Tweets
#
# Pull Tweets from the Twitter API (using Tweepy) and collect **tweets from 30 thought leaders and news outlets** using MongoDB as a task manager (manual distributed processing).

# %% [markdown]
# **Load lib codes & (private) Twitter keys**

# %%
# !pwd
# Out:
# /home/jovyan/work/Portfolio/Analyzing_Unstructured_Data_for_Finance

# %%
from os import chdir
chdir('/home/jovyan/work/Portfolio/Analyzing_Unstructured_Data_for_Finance/')

from lib import *
# suppress_warnings()
from lib.twitter_keys import my_keys

# %%
# !pip install pymongo pyquery tweepy
import pymongo
import tweepy
# Out:
# Requirement already satisfied (use --upgrade to upgrade): pymongo in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): pyquery in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): tweepy in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): cssselect>0.7.9 in /opt/conda/lib/python3.5/site-packages (from pyquery)
# Requirement already satisfied (use --upgrade to upgrade): lxml>=2.1 in /opt/conda/lib/python3.5/site-packages (from pyquery)
# Requirement already satisfied (use --upgrade to upgrade): requests>=2.4.3 in /opt/conda/lib/python3.5/site-packages (from tweepy)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.7.3 in /opt/conda/lib/python3.5/site-packages (from tweepy)
# Requirement already satisfied (use --upgrade to upgrade): requests-oauthlib>=0.4.1 in /opt/conda/lib/python3.5/site-packages (from tweepy)
# Requirement already satisfied (use --upgrade to upgrade): oauthlib>=0.6.2 in /opt/conda/lib/python3.5/site-packages (from requests-oauthlib>=0.4.1->tweepy)
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# **Use AppAuth (instead of OAuth) to maximize Twitter API's Rate Limit**

# %%
# Replace the API_KEY and API_SECRET with your application's key and secret
auth = tweepy.AppAuthHandler(my_keys['CONSUMER_KEY'], my_keys['CONSUMER_SECRET'])

# Authorize twitter, initialize tweepy
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

if (not api):
    print ("Can't Authenticate")
    sys.exit(-1)

# %%
# Identify port for better security of MongoDB
cli = pymongo.MongoClient(host='52.27.11.214', port=27016)

# %%
# Instantiates when you put data in 
task_collection = cli.twitter_db.task_collection
completed_collection = cli.twitter_db.completed_collection

cli.twitter_db.collection_names()
# Out:
# ['completed_collection', 'task_collection']

# %%
print(task_collection.count())
print(completed_collection.count())
# Out:
# 30
# 94856

# %%
# task_collection.drop()
# completed_collection.drop()

# %% [markdown]
# **Implementing distributed processing from scratch**<br>
# We want to use MongoDB as a task manager so we can run multiple AWS instances to work on one query. This allows us to run our query faster, so instead of waiting for one code to run on one notebook, we can have multiple notebooks running the same code.
#
# First, I create a "lookup_list" that will be stored in a MongoDB collection called task_collection. My query will pull any item with a pending status, get those Tweets, and update the status from <u>pending</u> to <u>complete</u>.

# %% [markdown]
# <img src="data:image/png;base64,..." style="cursor:pointer;max-width:100%;" onclick="(function(img){if(img.wnd!=null&&!img.wnd.closed){img.wnd.focus();}else{var r=function(evt){if(evt.data=='ready'&&evt.source==img.wnd){img.wnd.postMessage(decodeURIComponent(img.getAttribute('src')),'*');window.removeEventListener('message',r);}};window.addEventListener('message',r);img.wnd=window.open('https://www.draw.io/?client=1&lightbox=1&edit=_blank');}})(this);"/>

# %%
twitter_30_df = pd.read_csv('/home/jovyan/work/Portfolio/Analyzing_Unstructured_Data_for_Finance/data/1.twitter_users_30.csv', sep=',', encoding='latin-1')
handle = list(twitter_30_df['Handle'])

# %%
lookup_list = []
for h in handle:
    lookup_dict = {'handle': h,
                   'status': 'pending'}
    lookup_list.append(lookup_dict)

# %%
lookup_list
# Out:
# [{'handle': 'BarackObama', 'status': 'pending'},
#  {'handle': 'cnnbrk', 'status': 'pending'},
#  {'handle': 'BillGates', 'status': 'pending'},
#  {'handle': 'realDonaldTrump', 'status': 'pending'},
#  {'handle': 'TheEconomist', 'status': 'pending'},
#  {'handle': 'jimcramer', 'status': 'pending'},
#  {'handle': 'HillaryClinton', 'status': 'pending'},
#  {'handle': 'TechCrunch', 'status': 'pending'},
#  {'handle': 'elonmusk', 'status': 'pending'},
#  {'handle': 'NewYorker', 'status': 'pending'},
#  {'handle': 'mcuban', 'status': 'pending'},
#  {'handle': 'SeekingAlpha', 'status': 'pending'},
#  {'handle': 'MarketWatch', 'status': 'pending'},
#  {'handle': 'CNBC', 'status': 'pending'},
#  {'handle': 'Forbes', 'status': 'pending'},
#  {'handle': 'sacca', 'status': 'pending'},
#  {'handle': 'MktsInsider', 'status': 'pending'},
#  {'handle': 'ForbesInvestor', 'status': 'pending'},
#  {'handle': 'themotleyfool', 'status': 'pending'},
#  {'handle': 'ReformedBroker', 'status': 'pending'},
#  {'handle': 'StockTwits', 'status': 'pending'},
#  {'handle': 'steve_hanke', 'status': 'pending'},
#  {'handle': 'MONEY', 'status': 'pending'},
#  {'handle': 'ReutersInsider', 'status': 'pending'},
#  {'handle': 'barronsonline', 'status': 'pending'},
#  {'handle': 'zerohedge', 'status': 'pending'},
#  {'handle': 'abnormalreturns', 'status': 'pending'},
#  {'handle': 'WSJMoneyBeat', 'status': 'pending'},
#  {'handle': 'FinancialTimes', 'status': 'pending'},
#  {'handle': 'markets', 'status': 'pending'}]

# %%
for dictionary in lookup_list:
    task_collection.insert_one(dictionary)

# %%
task_collection.count()
# Out:
# 30

# %%
def get_tweets_to_mongo(lookup):

    maxTweets = 10000000 # Some arbitrary large number
    tweetsPerQry = 200  # this is the max the API permits

    # If results from a specific ID onwards are reqd, set since_id to that ID.
    # else default to no lower limit, go as far back as API allows
    sinceId = None

    # If results only below a specific ID are, set max_id to that ID.
    # else default to no upper limit, start from the most recent tweet matching the search query.
    max_id = -1E10

    tweetCount = 0
    while tweetCount < maxTweets:
        try:
            if (max_id <= 0):
                if (not sinceId):
                    new_tweets = api.user_timeline(screen_name = lookup, count=tweetsPerQry)
                else:
                    new_tweets = api.user_timeline(screen_name = lookup, count=tweetsPerQry,
                                                    since_id=sinceId)
            else:

                if (not sinceId):
                    new_tweets = api.user_timeline(screen_name = lookup, count=tweetsPerQry,
                                                    max_id=str(max_id - 1))
                else:
                    new_tweets = api.user_timeline(screen_name = lookup, count=tweetsPerQry,
                                                    max_id=str(max_id - 1),
                                                    since_id=sinceId)
            if not new_tweets:
                print("No more tweets found")
                break
            for tweet in new_tweets:
                tweet_dict = {'username': tweet.user.screen_name,
                              'timestamp': tweet.created_at, 
                              'text': tweet.text.encode("utf-8")}
                mongo_response = completed_collection.insert_one(tweet_dict)

            tweetCount += len(new_tweets)
            print("Downloaded {0} tweets for user: {1}".format(tweetCount, lookup))
            max_id = new_tweets[-1].id  

        except tweepy.TweepError as e:
            # Just exit if any error
            task_collection.insert_one({'handle': lookup, 'status': 'failed'})
            print("some error : " + str(e))
            break

    print ("Downloaded {0} tweets for user: {1} & saved to Mongo\n".format(tweetCount, lookup))

# %%
from datetime import datetime
start = datetime.now()

while True:
    # Get a user from the mongo collection
    task = task_collection.find_one_and_delete({'status': 'pending'})

    if type(task) != dict:
        print('Done!')
        break

    # Assign the handle to task_handle
    task_handle = task['handle']
        
        
    get_tweets_to_mongo(task_handle)
    task_collection.insert_one({'handle': task['handle'], 'status': 'complete'})
    
end = datetime.now()
print(end - start)
# Out:
# Downloaded 200 tweets for user: BarackObama
# Downloaded 400 tweets for user: BarackObama
# Downloaded 600 tweets for user: BarackObama
# Downloaded 800 tweets for user: BarackObama
# Downloaded 1000 tweets for user: BarackObama
# Downloaded 1200 tweets for user: BarackObama
# Downloaded 1400 tweets for user: BarackObama
# Downloaded 1600 tweets for user: BarackObama
# Downloaded 1800 tweets for user: BarackObama
# Downloaded 2000 tweets for user: BarackObama
# Downloaded 2200 tweets for user: BarackObama
# Downloaded 2399 tweets for user: BarackObama
# Downloaded 2599 tweets for user: BarackObama
# Downloaded 2796 tweets for user: BarackObama
# Downloaded 2996 tweets for user: BarackObama
# Downloaded 3196 tweets for user: BarackObama
# Downloaded 3234 tweets for user: BarackObama
# No more tweets found
# Downloaded 3234 tweets for user: BarackObama & saved to Mongo
#
# Downloaded 200 tweets for user: cnnbrk
# Downloaded 400 tweets for user: cnnbrk
# Downloaded 600 tweets for user: cnnbrk
# Downloaded 800 tweets for user: cnnbrk
# Downloaded 1000 tweets for user: cnnbrk
# Downloaded 1200 tweets for user: cnnbrk
# Downloaded 1400 tweets for user: cnnbrk
# Downloaded 1600 tweets for user: cnnbrk
# Downloaded 1800 tweets for user: cnnbrk
# Downloaded 2000 tweets for user: cnnbrk
# Downloaded 2200 tweets for user: cnnbrk
# Downloaded 2400 tweets for user: cnnbrk
# Downloaded 2600 tweets for user: cnnbrk
# Downloaded 2800 tweets for user: cnnbrk
# Downloaded 3000 tweets for user: cnnbrk
# Downloaded 3200 tweets for user: cnnbrk
# Downloaded 3223 tweets for user: cnnbrk
# No more tweets found
# Downloaded 3223 tweets for user: cnnbrk & saved to Mongo
#
# Downloaded 200 tweets for user: BillGates
# Downloaded 400 tweets for user: BillGates
# Downloaded 600 tweets for user: BillGates
# Downloaded 800 tweets for user: BillGates
# Downloaded 1000 tweets for user: BillGates
# Downloaded 1200 tweets for user: BillGates
# Downloaded 1400 tweets for user: BillGates
# Downloaded 1600 tweets for user: BillGates
# Downloaded 1800 tweets for user: BillGates
# Downloaded 2000 tweets for user: BillGates
# Downloaded 2200 tweets for user: BillGates
# Downloaded 2388 tweets for user: BillGates
# No more tweets found
# Downloaded 2388 tweets for user: BillGates & saved to Mongo
#
# Downloaded 200 tweets for user: realDonaldTrump
# Downloaded 400 tweets for user: realDonaldTrump
# Downloaded 600 tweets for user: realDonaldTrump
# Downloaded 800 tweets for user: realDonaldTrump
# Downloaded 1000 tweets for user: realDonaldTrump
# Downloaded 1199 tweets for user: realDonaldTrump
# Downloaded 1399 tweets for user: realDonaldTrump
# Downloaded 1599 tweets for user: realDonaldTrump
# Downloaded 1799 tweets for user: realDonaldTrump
# Downloaded 1999 tweets for user: realDonaldTrump
# Downloaded 2199 tweets for user: realDonaldTrump
# Downloaded 2399 tweets for user: realDonaldTrump
# Downloaded 2599 tweets for user: realDonaldTrump
# Downloaded 2799 tweets for user: realDonaldTrump
# Downloaded 2999 tweets for user: realDonaldTrump
# Downloaded 3199 tweets for user: realDonaldTrump
# Downloaded 3228 tweets for user: realDonaldTrump
# No more tweets found
# Downloaded 3228 tweets for user: realDonaldTrump & saved to Mongo
#
# Downloaded 200 tweets for user: TheEconomist
# Downloaded 400 tweets for user: TheEconomist
# Downloaded 600 tweets for user: TheEconomist
# Downloaded 800 tweets for user: TheEconomist
# Downloaded 1000 tweets for user: TheEconomist
# Downloaded 1200 tweets for user: TheEconomist
# Downloaded 1400 tweets for user: TheEconomist
# Downloaded 1600 tweets for user: TheEconomist
# Downloaded 1800 tweets for user: TheEconomist
# Downloaded 2000 tweets for user: TheEconomist
# Downloaded 2200 tweets for user: TheEconomist
# Downloaded 2400 tweets for user: TheEconomist
# Downloaded 2600 tweets for user: TheEconomist
# Downloaded 2800 tweets for user: TheEconomist
# Downloaded 3000 tweets for user: TheEconomist
# Downloaded 3200 tweets for user: TheEconomist
# Downloaded 3250 tweets for user: TheEconomist
# No more tweets found
# Downloaded 3250 tweets for user: TheEconomist & saved to Mongo
#
# Downloaded 200 tweets for user: jimcramer
# Downloaded 400 tweets for user: jimcramer
# Downloaded 600 tweets for user: jimcramer
# Downloaded 800 tweets for user: jimcramer
# Downloaded 1000 tweets for user: jimcramer
# Downloaded 1200 tweets for user: jimcramer
# Downloaded 1400 tweets for user: jimcramer
# Downloaded 1600 tweets for user: jimcramer
# Downloaded 1800 tweets for user: jimcramer
# Downloaded 2000 tweets for user: jimcramer
# Downloaded 2200 tweets for user: jimcramer
# Downloaded 2400 tweets for user: jimcramer
# Downloaded 2600 tweets for user: jimcramer
# Downloaded 2800 tweets for user: jimcramer
# Downloaded 3000 tweets for user: jimcramer
# Downloaded 3200 tweets for user: jimcramer
# Downloaded 3244 tweets for user: jimcramer
# No more tweets found
# Downloaded 3244 tweets for user: jimcramer & saved to Mongo
#
# Downloaded 200 tweets for user: HillaryClinton
# Downloaded 400 tweets for user: HillaryClinton
# Downloaded 600 tweets for user: HillaryClinton
# Downloaded 800 tweets for user: HillaryClinton
# Downloaded 1000 tweets for user: HillaryClinton
# Downloaded 1200 tweets for user: HillaryClinton
# Downloaded 1399 tweets for user: HillaryClinton
# Downloaded 1599 tweets for user: HillaryClinton
# Downloaded 1799 tweets for user: HillaryClinton
# Downloaded 1999 tweets for user: HillaryClinton
# Downloaded 2199 tweets for user: HillaryClinton
# Downloaded 2399 tweets for user: HillaryClinton
# Downloaded 2599 tweets for user: HillaryClinton
# Downloaded 2799 tweets for user: HillaryClinton
# Downloaded 2999 tweets for user: HillaryClinton
# Downloaded 3199 tweets for user: HillaryClinton
# Downloaded 3236 tweets for user: HillaryClinton
# No more tweets found
# Downloaded 3236 tweets for user: HillaryClinton & saved to Mongo
#
# Downloaded 200 tweets for user: TechCrunch
# Downloaded 400 tweets for user: TechCrunch
# Downloaded 600 tweets for user: TechCrunch
# Downloaded 800 tweets for user: TechCrunch
# Downloaded 1000 tweets for user: TechCrunch
# Downloaded 1200 tweets for user: TechCrunch
# Downloaded 1400 tweets for user: TechCrunch
# Downloaded 1600 tweets for user: TechCrunch
# Downloaded 1800 tweets for user: TechCrunch
# Downloaded 2000 tweets for user: TechCrunch
# Downloaded 2200 tweets for user: TechCrunch
# Downloaded 2400 tweets for user: TechCrunch
# Downloaded 2600 tweets for user: TechCrunch
# Downloaded 2800 tweets for user: TechCrunch
# Downloaded 3000 tweets for user: TechCrunch
# Downloaded 3200 tweets for user: TechCrunch
# Downloaded 3214 tweets for user: TechCrunch
# No more tweets found
# Downloaded 3214 tweets for user: TechCrunch & saved to Mongo
#
# Downloaded 200 tweets for user: elonmusk
# Downloaded 400 tweets for user: elonmusk
# Downloaded 600 tweets for user: elonmusk
# Downloaded 800 tweets for user: elonmusk
# Downloaded 1000 tweets for user: elonmusk
# Downloaded 1200 tweets for user: elonmusk
# Downloaded 1399 tweets for user: elonmusk
# Downloaded 1599 tweets for user: elonmusk
# Downloaded 1799 tweets for user: elonmusk
# Downloaded 1999 tweets for user: elonmusk
# Downloaded 2198 tweets for user: elonmusk
# Downloaded 2398 tweets for user: elonmusk
# Downloaded 2598 tweets for user: elonmusk
# Downloaded 2798 tweets for user: elonmusk
# Downloaded 2998 tweets for user: elonmusk
# Downloaded 3098 tweets for user: elonmusk
# No more tweets found
# Downloaded 3098 tweets for user: elonmusk & saved to Mongo
#
# Downloaded 200 tweets for user: NewYorker
# Downloaded 400 tweets for user: NewYorker
# Downloaded 600 tweets for user: NewYorker
# Downloaded 800 tweets for user: NewYorker
# Downloaded 1000 tweets for user: NewYorker
# Downloaded 1200 tweets for user: NewYorker
# Downloaded 1400 tweets for user: NewYorker
# Downloaded 1600 tweets for user: NewYorker
# Downloaded 1800 tweets for user: NewYorker
# Downloaded 2000 tweets for user: NewYorker
# Downloaded 2200 tweets for user: NewYorker
# Downloaded 2400 tweets for user: NewYorker
# Downloaded 2600 tweets for user: NewYorker
# Downloaded 2800 tweets for user: NewYorker
# Downloaded 3000 tweets for user: NewYorker
# Downloaded 3200 tweets for user: NewYorker
# Downloaded 3203 tweets for user: NewYorker
# No more tweets found
# Downloaded 3203 tweets for user: NewYorker & saved to Mongo
#
# Downloaded 200 tweets for user: mcuban
# Downloaded 400 tweets for user: mcuban
# Downloaded 600 tweets for user: mcuban
# Downloaded 800 tweets for user: mcuban
# Downloaded 1000 tweets for user: mcuban
# Downloaded 1199 tweets for user: mcuban
# Downloaded 1398 tweets for user: mcuban
# Downloaded 1597 tweets for user: mcuban
# Downloaded 1796 tweets for user: mcuban
# Downloaded 1986 tweets for user: mcuban
# Downloaded 2161 tweets for user: mcuban
# Downloaded 2236 tweets for user: mcuban
# No more tweets found
# Downloaded 2236 tweets for user: mcuban & saved to Mongo
#
# Downloaded 200 tweets for user: SeekingAlpha
# Downloaded 400 tweets for user: SeekingAlpha
# Downloaded 600 tweets for user: SeekingAlpha
# Downloaded 800 tweets for user: SeekingAlpha
# Downloaded 1000 tweets for user: SeekingAlpha
# Downloaded 1200 tweets for user: SeekingAlpha
# Downloaded 1400 tweets for user: SeekingAlpha
# Downloaded 1600 tweets for user: SeekingAlpha
# Downloaded 1800 tweets for user: SeekingAlpha
# Downloaded 2000 tweets for user: SeekingAlpha
# Downloaded 2200 tweets for user: SeekingAlpha
# Downloaded 2400 tweets for user: SeekingAlpha
# Downloaded 2600 tweets for user: SeekingAlpha
# Downloaded 2800 tweets for user: SeekingAlpha
# Downloaded 3000 tweets for user: SeekingAlpha
# Downloaded 3200 tweets for user: SeekingAlpha
# Downloaded 3244 tweets for user: SeekingAlpha
# No more tweets found
# Downloaded 3244 tweets for user: SeekingAlpha & saved to Mongo
#
# Downloaded 200 tweets for user: MarketWatch
# Downloaded 400 tweets for user: MarketWatch
# Downloaded 600 tweets for user: MarketWatch
# Downloaded 800 tweets for user: MarketWatch
# Downloaded 1000 tweets for user: MarketWatch
# Downloaded 1200 tweets for user: MarketWatch
# Downloaded 1400 tweets for user: MarketWatch
# Downloaded 1600 tweets for user: MarketWatch
# Downloaded 1800 tweets for user: MarketWatch
# Downloaded 2000 tweets for user: MarketWatch
# Downloaded 2200 tweets for user: MarketWatch
# Downloaded 2400 tweets for user: MarketWatch
# Downloaded 2600 tweets for user: MarketWatch
# Downloaded 2800 tweets for user: MarketWatch
# Downloaded 3000 tweets for user: MarketWatch
# Downloaded 3200 tweets for user: MarketWatch
# Downloaded 3245 tweets for user: MarketWatch
# No more tweets found
# Downloaded 3245 tweets for user: MarketWatch & saved to Mongo
#
# Downloaded 200 tweets for user: CNBC
# Downloaded 400 tweets for user: CNBC
# Downloaded 600 tweets for user: CNBC
# Downloaded 800 tweets for user: CNBC
# Downloaded 1000 tweets for user: CNBC
# Downloaded 1200 tweets for user: CNBC
# Downloaded 1400 tweets for user: CNBC
# Downloaded 1600 tweets for user: CNBC
# Downloaded 1800 tweets for user: CNBC
# Downloaded 2000 tweets for user: CNBC
# Downloaded 2200 tweets for user: CNBC
# Downloaded 2400 tweets for user: CNBC
# Downloaded 2600 tweets for user: CNBC
# Downloaded 2800 tweets for user: CNBC
# Downloaded 3000 tweets for user: CNBC
# Downloaded 3200 tweets for user: CNBC
# Downloaded 3238 tweets for user: CNBC
# Downloaded 3239 tweets for user: CNBC
# No more tweets found
# Downloaded 3239 tweets for user: CNBC & saved to Mongo
#
# Downloaded 200 tweets for user: Forbes
# Downloaded 400 tweets for user: Forbes
# Downloaded 600 tweets for user: Forbes
# Downloaded 800 tweets for user: Forbes
# Downloaded 1000 tweets for user: Forbes
# Downloaded 1200 tweets for user: Forbes
# Downloaded 1400 tweets for user: Forbes
# Downloaded 1600 tweets for user: Forbes
# Downloaded 1800 tweets for user: Forbes
# Downloaded 2000 tweets for user: Forbes
# Downloaded 2200 tweets for user: Forbes
# Downloaded 2400 tweets for user: Forbes
# Downloaded 2600 tweets for user: Forbes
# Downloaded 2800 tweets for user: Forbes
# Downloaded 3000 tweets for user: Forbes
# Downloaded 3200 tweets for user: Forbes
# Downloaded 3237 tweets for user: Forbes
# No more tweets found
# Downloaded 3237 tweets for user: Forbes & saved to Mongo
#
# Downloaded 199 tweets for user: sacca
# Downloaded 398 tweets for user: sacca
# Downloaded 598 tweets for user: sacca
# Downloaded 796 tweets for user: sacca
# Downloaded 996 tweets for user: sacca
# Downloaded 1196 tweets for user: sacca
# Downloaded 1396 tweets for user: sacca
# Downloaded 1596 tweets for user: sacca
# Downloaded 1795 tweets for user: sacca
# Downloaded 1994 tweets for user: sacca
# Downloaded 2194 tweets for user: sacca
# Downloaded 2394 tweets for user: sacca
# Downloaded 2594 tweets for user: sacca
# Downloaded 2794 tweets for user: sacca
# Downloaded 2993 tweets for user: sacca
# Downloaded 3193 tweets for user: sacca
# Downloaded 3235 tweets for user: sacca
# No more tweets found
# Downloaded 3235 tweets for user: sacca & saved to Mongo
#
# Downloaded 200 tweets for user: MktsInsider
# Downloaded 400 tweets for user: MktsInsider
# Downloaded 600 tweets for user: MktsInsider
# Downloaded 800 tweets for user: MktsInsider
# Downloaded 1000 tweets for user: MktsInsider
# Downloaded 1200 tweets for user: MktsInsider
# Downloaded 1400 tweets for user: MktsInsider
# Downloaded 1600 tweets for user: MktsInsider
# Downloaded 1800 tweets for user: MktsInsider
# Downloaded 2000 tweets for user: MktsInsider
# Downloaded 2200 tweets for user: MktsInsider
# Downloaded 2400 tweets for user: MktsInsider
# Downloaded 2600 tweets for user: MktsInsider
# Downloaded 2800 tweets for user: MktsInsider
# Downloaded 3000 tweets for user: MktsInsider
# Downloaded 3200 tweets for user: MktsInsider
# Downloaded 3243 tweets for user: MktsInsider
# No more tweets found
# Downloaded 3243 tweets for user: MktsInsider & saved to Mongo
#
# Downloaded 200 tweets for user: ForbesInvestor
# Downloaded 400 tweets for user: ForbesInvestor
# Downloaded 600 tweets for user: ForbesInvestor
# Downloaded 800 tweets for user: ForbesInvestor
# Downloaded 1000 tweets for user: ForbesInvestor
# Downloaded 1200 tweets for user: ForbesInvestor
# Downloaded 1400 tweets for user: ForbesInvestor
# Downloaded 1600 tweets for user: ForbesInvestor
# Downloaded 1800 tweets for user: ForbesInvestor
# Downloaded 2000 tweets for user: ForbesInvestor
# Downloaded 2200 tweets for user: ForbesInvestor
# Downloaded 2400 tweets for user: ForbesInvestor
# Downloaded 2600 tweets for user: ForbesInvestor
# Downloaded 2800 tweets for user: ForbesInvestor
# Downloaded 3000 tweets for user: ForbesInvestor
# Downloaded 3200 tweets for user: ForbesInvestor
# Downloaded 3241 tweets for user: ForbesInvestor
# No more tweets found
# Downloaded 3241 tweets for user: ForbesInvestor & saved to Mongo
#
# Downloaded 200 tweets for user: themotleyfool
# Downloaded 400 tweets for user: themotleyfool
# Downloaded 600 tweets for user: themotleyfool
# Downloaded 800 tweets for user: themotleyfool
# Downloaded 1000 tweets for user: themotleyfool
# Downloaded 1200 tweets for user: themotleyfool
# Downloaded 1400 tweets for user: themotleyfool
# Downloaded 1600 tweets for user: themotleyfool
# Downloaded 1800 tweets for user: themotleyfool
# Downloaded 2000 tweets for user: themotleyfool
# Downloaded 2200 tweets for user: themotleyfool
# Downloaded 2400 tweets for user: themotleyfool
# Downloaded 2600 tweets for user: themotleyfool
# Downloaded 2800 tweets for user: themotleyfool
# Downloaded 2999 tweets for user: themotleyfool
# Downloaded 3199 tweets for user: themotleyfool
# Downloaded 3214 tweets for user: themotleyfool
# No more tweets found
# Downloaded 3214 tweets for user: themotleyfool & saved to Mongo
#
# Downloaded 200 tweets for user: ReformedBroker
# Downloaded 400 tweets for user: ReformedBroker
# Downloaded 600 tweets for user: ReformedBroker
# Downloaded 800 tweets for user: ReformedBroker
# Downloaded 1000 tweets for user: ReformedBroker
# Downloaded 1200 tweets for user: ReformedBroker
# Downloaded 1400 tweets for user: ReformedBroker
# Downloaded 1600 tweets for user: ReformedBroker
# Downloaded 1800 tweets for user: ReformedBroker
# Downloaded 2000 tweets for user: ReformedBroker
# Downloaded 2200 tweets for user: ReformedBroker
# Downloaded 2400 tweets for user: ReformedBroker
# Downloaded 2600 tweets for user: ReformedBroker
# Downloaded 2800 tweets for user: ReformedBroker
# Downloaded 3000 tweets for user: ReformedBroker
# Downloaded 3200 tweets for user: ReformedBroker
# Downloaded 3210 tweets for user: ReformedBroker
# No more tweets found
# Downloaded 3210 tweets for user: ReformedBroker & saved to Mongo
#
# Downloaded 200 tweets for user: StockTwits
# Downloaded 400 tweets for user: StockTwits
# Downloaded 600 tweets for user: StockTwits
# Downloaded 800 tweets for user: StockTwits
# Downloaded 1000 tweets for user: StockTwits
# Downloaded 1200 tweets for user: StockTwits
# Downloaded 1400 tweets for user: StockTwits
# Downloaded 1600 tweets for user: StockTwits
# Downloaded 1800 tweets for user: StockTwits
# Downloaded 2000 tweets for user: StockTwits
# Downloaded 2200 tweets for user: StockTwits
# Downloaded 2400 tweets for user: StockTwits
# Downloaded 2600 tweets for user: StockTwits
# Downloaded 2800 tweets for user: StockTwits
# Downloaded 3000 tweets for user: StockTwits
# Downloaded 3200 tweets for user: StockTwits
# Downloaded 3215 tweets for user: StockTwits
# No more tweets found
# Downloaded 3215 tweets for user: StockTwits & saved to Mongo
#
# Downloaded 200 tweets for user: steve_hanke
# Downloaded 400 tweets for user: steve_hanke
# Downloaded 600 tweets for user: steve_hanke
# Downloaded 800 tweets for user: steve_hanke
# Downloaded 1000 tweets for user: steve_hanke
# Downloaded 1200 tweets for user: steve_hanke
# Downloaded 1400 tweets for user: steve_hanke
# Downloaded 1600 tweets for user: steve_hanke
# Downloaded 1800 tweets for user: steve_hanke
# Downloaded 2000 tweets for user: steve_hanke
# Downloaded 2200 tweets for user: steve_hanke
# Downloaded 2400 tweets for user: steve_hanke
# Downloaded 2600 tweets for user: steve_hanke
# Downloaded 2800 tweets for user: steve_hanke
# Downloaded 3000 tweets for user: steve_hanke
# Downloaded 3200 tweets for user: steve_hanke
# Downloaded 3249 tweets for user: steve_hanke
# No more tweets found
# Downloaded 3249 tweets for user: steve_hanke & saved to Mongo
#
# Downloaded 200 tweets for user: MONEY
# Downloaded 400 tweets for user: MONEY
# Downloaded 600 tweets for user: MONEY
# Downloaded 800 tweets for user: MONEY
# Downloaded 1000 tweets for user: MONEY
# Downloaded 1200 tweets for user: MONEY
# Downloaded 1400 tweets for user: MONEY
# Downloaded 1600 tweets for user: MONEY
# Downloaded 1800 tweets for user: MONEY
# Downloaded 2000 tweets for user: MONEY
# Downloaded 2200 tweets for user: MONEY
# Downloaded 2400 tweets for user: MONEY
# Downloaded 2600 tweets for user: MONEY
# Downloaded 2800 tweets for user: MONEY
# Downloaded 3000 tweets for user: MONEY
# Downloaded 3200 tweets for user: MONEY
# Downloaded 3207 tweets for user: MONEY
# No more tweets found
# Downloaded 3207 tweets for user: MONEY & saved to Mongo
#
# Downloaded 200 tweets for user: ReutersInsider
# Downloaded 400 tweets for user: ReutersInsider
# Downloaded 599 tweets for user: ReutersInsider
# Downloaded 799 tweets for user: ReutersInsider
# Downloaded 999 tweets for user: ReutersInsider
# Downloaded 1199 tweets for user: ReutersInsider
# Downloaded 1399 tweets for user: ReutersInsider
# Downloaded 1599 tweets for user: ReutersInsider
# Downloaded 1799 tweets for user: ReutersInsider
# Downloaded 1999 tweets for user: ReutersInsider
# Downloaded 2199 tweets for user: ReutersInsider
# Downloaded 2399 tweets for user: ReutersInsider
# Downloaded 2599 tweets for user: ReutersInsider
# Downloaded 2799 tweets for user: ReutersInsider
# Downloaded 2999 tweets for user: ReutersInsider
# Downloaded 3198 tweets for user: ReutersInsider
# Downloaded 3213 tweets for user: ReutersInsider
# No more tweets found
# Downloaded 3213 tweets for user: ReutersInsider & saved to Mongo
#
# Downloaded 200 tweets for user: barronsonline
# Downloaded 400 tweets for user: barronsonline
# Downloaded 600 tweets for user: barronsonline
# Downloaded 800 tweets for user: barronsonline
# Downloaded 1000 tweets for user: barronsonline
# Downloaded 1200 tweets for user: barronsonline
# Downloaded 1400 tweets for user: barronsonline
# Downloaded 1600 tweets for user: barronsonline
# Downloaded 1800 tweets for user: barronsonline
# Downloaded 2000 tweets for user: barronsonline
# Downloaded 2200 tweets for user: barronsonline
# Downloaded 2400 tweets for user: barronsonline
# Downloaded 2600 tweets for user: barronsonline
# Downloaded 2800 tweets for user: barronsonline
# Downloaded 3000 tweets for user: barronsonline
# Downloaded 3200 tweets for user: barronsonline
# Downloaded 3207 tweets for user: barronsonline
# No more tweets found
# Downloaded 3207 tweets for user: barronsonline & saved to Mongo
#
# Downloaded 200 tweets for user: zerohedge
# Downloaded 400 tweets for user: zerohedge
# Downloaded 600 tweets for user: zerohedge
# Downloaded 800 tweets for user: zerohedge
# Downloaded 1000 tweets for user: zerohedge
# Downloaded 1200 tweets for user: zerohedge
# Downloaded 1400 tweets for user: zerohedge
# Downloaded 1600 tweets for user: zerohedge
# Downloaded 1800 tweets for user: zerohedge
# Downloaded 2000 tweets for user: zerohedge
# Downloaded 2200 tweets for user: zerohedge
# Downloaded 2400 tweets for user: zerohedge
# Downloaded 2600 tweets for user: zerohedge
# Downloaded 2800 tweets for user: zerohedge
# Downloaded 3000 tweets for user: zerohedge
# Downloaded 3200 tweets for user: zerohedge
# Downloaded 3219 tweets for user: zerohedge
# No more tweets found
# Downloaded 3219 tweets for user: zerohedge & saved to Mongo
#
# Downloaded 200 tweets for user: abnormalreturns
# Downloaded 400 tweets for user: abnormalreturns
# Downloaded 600 tweets for user: abnormalreturns
# Downloaded 800 tweets for user: abnormalreturns
# Downloaded 1000 tweets for user: abnormalreturns
# Downloaded 1200 tweets for user: abnormalreturns
# Downloaded 1400 tweets for user: abnormalreturns
# Downloaded 1600 tweets for user: abnormalreturns
# Downloaded 1800 tweets for user: abnormalreturns
# Downloaded 2000 tweets for user: abnormalreturns
# Downloaded 2200 tweets for user: abnormalreturns
# Downloaded 2400 tweets for user: abnormalreturns
# Downloaded 2600 tweets for user: abnormalreturns
# Downloaded 2800 tweets for user: abnormalreturns
# Downloaded 3000 tweets for user: abnormalreturns
# Downloaded 3200 tweets for user: abnormalreturns
# Downloaded 3216 tweets for user: abnormalreturns
# No more tweets found
# Downloaded 3216 tweets for user: abnormalreturns & saved to Mongo
#
# Downloaded 200 tweets for user: WSJMoneyBeat
# Downloaded 400 tweets for user: WSJMoneyBeat
# Downloaded 600 tweets for user: WSJMoneyBeat
# Downloaded 800 tweets for user: WSJMoneyBeat
# Downloaded 1000 tweets for user: WSJMoneyBeat
# Downloaded 1200 tweets for user: WSJMoneyBeat
# Downloaded 1400 tweets for user: WSJMoneyBeat
# Downloaded 1600 tweets for user: WSJMoneyBeat
# Downloaded 1800 tweets for user: WSJMoneyBeat
# Downloaded 1999 tweets for user: WSJMoneyBeat
# Downloaded 2199 tweets for user: WSJMoneyBeat
# Downloaded 2398 tweets for user: WSJMoneyBeat
# Downloaded 2598 tweets for user: WSJMoneyBeat
# Downloaded 2798 tweets for user: WSJMoneyBeat
# Downloaded 2998 tweets for user: WSJMoneyBeat
# Downloaded 3198 tweets for user: WSJMoneyBeat
# Downloaded 3223 tweets for user: WSJMoneyBeat
# No more tweets found
# Downloaded 3223 tweets for user: WSJMoneyBeat & saved to Mongo
#
# Downloaded 200 tweets for user: FinancialTimes
# Downloaded 400 tweets for user: FinancialTimes
# Downloaded 600 tweets for user: FinancialTimes
# Downloaded 800 tweets for user: FinancialTimes
# Downloaded 1000 tweets for user: FinancialTimes
# Downloaded 1200 tweets for user: FinancialTimes
# Downloaded 1400 tweets for user: FinancialTimes
# Downloaded 1600 tweets for user: FinancialTimes
# Downloaded 1800 tweets for user: FinancialTimes
# Downloaded 2000 tweets for user: FinancialTimes
# Downloaded 2200 tweets for user: FinancialTimes
# Downloaded 2400 tweets for user: FinancialTimes
# Downloaded 2600 tweets for user: FinancialTimes
# Downloaded 2800 tweets for user: FinancialTimes
# Downloaded 3000 tweets for user: FinancialTimes
# Downloaded 3200 tweets for user: FinancialTimes
# Downloaded 3221 tweets for user: FinancialTimes
# No more tweets found
# Downloaded 3221 tweets for user: FinancialTimes & saved to Mongo
#
# Downloaded 200 tweets for user: markets
# Downloaded 400 tweets for user: markets
# Downloaded 600 tweets for user: markets
# Downloaded 800 tweets for user: markets
# Downloaded 1000 tweets for user: markets
# Downloaded 1200 tweets for user: markets
# Downloaded 1400 tweets for user: markets
# Downloaded 1600 tweets for user: markets
# Downloaded 1800 tweets for user: markets
# Downloaded 2000 tweets for user: markets
# Downloaded 2200 tweets for user: markets
# Downloaded 2400 tweets for user: markets
# Downloaded 2600 tweets for user: markets
# Downloaded 2800 tweets for user: markets
# Downloaded 3000 tweets for user: markets
# Downloaded 3200 tweets for user: markets
# Downloaded 3224 tweets for user: markets
# No more tweets found
# Downloaded 3224 tweets for user: markets & saved to Mongo
#
# Done!
# 0:04:41.801841

# %%
completed_collection.count()
# Out:
# 94856

# %%
# Look at the statuses in task_collection. Everything should be "complete."
curs = task_collection.find()
list_of_docs = []
for i in range(curs.count()):
    list_of_docs.append(curs.next())
    df = pd.DataFrame(list_of_docs)
df
# Out:
#                          _id           handle    status
# 0   593deb7857bbd40476642ee0      BarackObama  complete
# 1   593deb8257bbd40476643b78           cnnbrk  complete
# 2   593deb8857bbd404766444cd        BillGates  complete
# 3   593deb9257bbd4047664516a  realDonaldTrump  complete
# 4   593deb9a57bbd40476645e1d     TheEconomist  complete
# 5   593deba857bbd40476646aca        jimcramer  complete
# 6   593debb157bbd4047664776f   HillaryClinton  complete
# 7   593debbb57bbd404766483fe       TechCrunch  complete
# 8   593debc357bbd40476649019         elonmusk  complete
# 9   593debcc57bbd40476649c9d        NewYorker  complete
# 10  593debd357bbd4047664a55a           mcuban  complete
# 11  593debdc57bbd4047664b207     SeekingAlpha  complete
# 12  593debe557bbd4047664beb5      MarketWatch  complete
# 13  593debed57bbd4047664cb5d             CNBC  complete
# 14  593debf757bbd4047664d803           Forbes  complete
# 15  593dec0357bbd4047664e4a7            sacca  complete
# 16  593dec0c57bbd4047664f153      MktsInsider  complete
# 17  593dec1557bbd4047664fdfd   ForbesInvestor  complete
# 18  593dec1e57bbd40476650a8c    themotleyfool  complete
# 19  593dec2757bbd40476651717   ReformedBroker  complete
# 20  593dec3057bbd404766523a7       StockTwits  complete
# 21  593dec3957bbd40476653059      steve_hanke  complete
# 22  593dec4257bbd40476653ce1            MONEY  complete
# 23  593dec4e57bbd4047665496f   ReutersInsider  complete
# 24  593dec5a57bbd404766555f7    barronsonline  complete
# 25  593dec6357bbd4047665628b        zerohedge  complete
# 26  593dec6c57bbd40476656f1c  abnormalreturns  complete
# 27  593dec7657bbd40476657bb4     WSJMoneyBeat  complete
# 28  593dec7e57bbd4047665884a   FinancialTimes  complete
# 29  593dec8957bbd404766594e3          markets  complete

# %%
# A faster way of getting data out of a collection
tweets_list = [document for document in completed_collection.find()]
tweets_df = pd.DataFrame(tweets_list)
tweets_df.head()
# Out:
#                         _id  \
# 0  593deb7057bbd4047664223e
# 1  593deb7057bbd4047664223f
# 2  593deb7057bbd40476642240
# 3  593deb7057bbd40476642241
# 4  593deb7057bbd40476642242
#
#                                                 text           timestamp  \
# 0  On this National Gun Violence Awareness Day, l... 2017-06-02 17:35:54
# 1  Forever grateful for the service and sacrifice... 2017-05-29 13:09:16
# 2  Good to see my friend Prince Harry in London t... 2017-05-27 13:15:25
# 3  Through faith, love, and resolve the character... 2017-05-25 14:13:35
# 4  Our hearts go out to those killed and wounded ... 2017-05-23 16:56:14
#
#       username
# 0  BarackObama
# 1  BarackObama
# 2  BarackObama
# 3  BarackObama
# 4  BarackObama

# %%
# Looks like we successfully got all our data from MongoDB
tweets_df.shape
# Out:
# (94856, 4)
