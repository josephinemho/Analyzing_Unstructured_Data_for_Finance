# %% [markdown]
# # Part 3 -- Get Target Data (S&P 500)
#
# Get our target data (the entire S&P 500 index, made up of 500 individual stocks) and perform calculations. We want to look at the Close price to determine whether stocks went up/down/neutral compared to the previous day. This will be a **classification model** and we will set our threshold of up/down/neutral to a change of 2%.

# %% [markdown]
# **Load lib codes**

# %%
from os import chdir
chdir('/home/jovyan/work/Portfolio/Analyzing_Unstructured_Data_for_Finance/')

from lib import *
# suppress_warnings()

# %%
# !pip install pandas-datareader pymongo pyquery
# Out:
# Requirement already satisfied (use --upgrade to upgrade): pandas-datareader in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): pymongo in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): pyquery in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied (use --upgrade to upgrade): pandas>=0.17.0 in /opt/conda/lib/python3.5/site-packages (from pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): requests>=2.3.0 in /opt/conda/lib/python3.5/site-packages (from pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): requests-file in /opt/conda/lib/python3.5/site-packages (from pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): requests-ftp in /opt/conda/lib/python3.5/site-packages (from pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): cssselect>0.7.9 in /opt/conda/lib/python3.5/site-packages (from pyquery)
# Requirement already satisfied (use --upgrade to upgrade): lxml>=2.1 in /opt/conda/lib/python3.5/site-packages (from pyquery)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil>=2 in /opt/conda/lib/python3.5/site-packages (from pandas>=0.17.0->pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): pytz>=2011k in /opt/conda/lib/python3.5/site-packages (from pandas>=0.17.0->pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.7.0 in /opt/conda/lib/python3.5/site-packages (from pandas>=0.17.0->pandas-datareader)
# Requirement already satisfied (use --upgrade to upgrade): six in /opt/conda/lib/python3.5/site-packages (from requests-file->pandas-datareader)
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pymongo
import pandas_datareader.data as web
import bs4 as bs
import requests

# %% [markdown]
# **Web-scrape most recent list of S&P 500 stocks from Wikipedia and add to MongoDB**

# %%
# Identify port for better security of MongoDB
cli = pymongo.MongoClient(host='52.27.11.214', port=27016)

# %%
# Instantiates when you put data in 
sp500_collection = cli.stocks_db.sp500_collection
stocks_collection = cli.stocks_db.stocks_collection
cli.stocks_db.collection_names()
# Out:
# ['sp500_collection', 'stocks_collection']

# %%
print(sp500_collection.count())
print(stocks_collection.count())
# Out:
# 505
# 943687

# %%
# sp500_collection.drop()
# stocks_collection.drop()

# %%
def get_sp500_to_mongo():
    resp = requests.get('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'html5lib')
    table = soup.find('table', {'class': 'wikitable sortable'})
    for row in table.findAll('tr')[1:]:
        stock = row.findAll('td')[0].text
        sp500_dict = {
            'stock': stock,
            'status': 'pending'
        }
        sp500_collection.insert_one(sp500_dict)
get_sp500_to_mongo()

# %%
print(sp500_collection.count())
print(stocks_collection.count())
# Out:
# 505
# 0

# %%
sp500_list = [document for document in sp500_collection.find()]
sp500_df = pd.DataFrame(sp500_list)
sp500_df.head()
# Out:
#                         _id   status stock
# 0  593e12ad57bbd405c4fb0f7f  pending   MMM
# 1  593e12ad57bbd405c4fb0f80  pending   ABT
# 2  593e12ad57bbd405c4fb0f81  pending  ABBV
# 3  593e12ad57bbd405c4fb0f82  pending   ACN
# 4  593e12ad57bbd405c4fb0f83  pending  ATVI

# %% [markdown]
# **Get stock data from Google Finance and add it to our sp500_collection in mongo**

# %%
# Takes argument of a stock and returns dataframe with stock column
def get_stocks(stock):
    try:
        start = dt.datetime(2009,6,11)
        end = dt.datetime(2017,6,11)
        df = web.DataReader(stock, 'google', start, end)
        df = df.reset_index()
        df['Stock'] = stock
        print('{} added for {}'.format(len(df), stock))
        return df
    except Exception as e:
        print('Error: e')
        pass

# Takes argument of a dataframe AND a mongo collection, turns it into a list of dictionaries and inserts into collection
def df_to_mongo(df, collection):
    try:
        stock_dict_list = list(df.to_dict(orient='index').values())
        collection.insert_many(stock_dict_list)
        sp500_collection.insert_one({'stock': stock, 'status': 'complete'})
        print('Successfully added to mongo')
    except Exception as e:
        sp500_collection.insert_one({'stock': stock, 'status': 'failed'})
        print('Error: e')
        pass

# Third function that does everything using both functions:
def get_stocks_to_mongo(stock):
    df = get_stocks(stock)
    df_to_mongo(df, stocks_collection)

# %%
start = datetime.now()

while True:
    # Get a user from mongo collection
    sp500 = sp500_collection.find_one_and_delete({'status': 'pending'})

    if type(sp500) != dict:
        print('Done!')
        break

    # Assign the stock to stock
    stock = sp500['stock']
        
    get_stocks_to_mongo(stock)

end = datetime.now()
print(end - start)
# Out:
# 2014 added for MMM
# Successfully added to mongo
# 2014 added for ABT
# Successfully added to mongo
# 1133 added for ABBV
# Successfully added to mongo
# 2014 added for ACN
# Successfully added to mongo
# 2013 added for ATVI
# Successfully added to mongo
# 2014 added for AYI
# Successfully added to mongo
# 2013 added for ADBE
# Successfully added to mongo
# 2012 added for AMD
# Successfully added to mongo
# 2014 added for AAP
# Successfully added to mongo
# 2014 added for AES
# Successfully added to mongo
# 2014 added for AET
# Successfully added to mongo
# 2014 added for AMG
# Successfully added to mongo
# 2014 added for AFL
# Successfully added to mongo
# 2014 added for A
# Successfully added to mongo
# 2014 added for APD
# Successfully added to mongo
# 2013 added for AKAM
# Successfully added to mongo
# 2014 added for ALK
# Successfully added to mongo
# 2014 added for ALB
# Successfully added to mongo
# 2014 added for ARE
# Successfully added to mongo
# 2013 added for ALXN
# Successfully added to mongo
# 896 added for ALLE
# Successfully added to mongo
# 930 added for AGN
# Successfully added to mongo
# 2014 added for ADS
# Successfully added to mongo
# 2014 added for LNT
# Successfully added to mongo
# 2014 added for ALL
# Successfully added to mongo
# 2013 added for GOOGL
# Successfully added to mongo
# 2013 added for GOOG
# Successfully added to mongo
# 2014 added for MO
# Successfully added to mongo
# 2013 added for AMZN
# Successfully added to mongo
# 2014 added for AEE
# Successfully added to mongo
# 882 added for AAL
# Successfully added to mongo
# 2014 added for AEP
# Successfully added to mongo
# 2014 added for AXP
# Successfully added to mongo
# 2014 added for AIG
# Successfully added to mongo
# 645 added for AMT
# Successfully added to mongo
# 2014 added for AWK
# Successfully added to mongo
# 2014 added for AMP
# Successfully added to mongo
# 2014 added for ABC
# Successfully added to mongo
# 2014 added for AME
# Successfully added to mongo
# 2013 added for AMGN
# Successfully added to mongo
# 2014 added for APH
# Successfully added to mongo
# 2014 added for APC
# Successfully added to mongo
# 1306 added for ADI
# Successfully added to mongo
# 2014 added for ANTM
# Successfully added to mongo
# 1147 added for AON
# Successfully added to mongo
# 2014 added for APA
# Successfully added to mongo
# 2014 added for AIV
# Successfully added to mongo
# 2013 added for AAPL
# Successfully added to mongo
# 2012 added for AMAT
# Successfully added to mongo
# 2014 added for ADM
# Successfully added to mongo
# 2014 added for ARNC
# Successfully added to mongo
# 2014 added for AJG
# Successfully added to mongo
# 2014 added for AIZ
# Successfully added to mongo
# 2014 added for T
# Successfully added to mongo
# 2013 added for ADSK
# Successfully added to mongo
# 2013 added for ADP
# Successfully added to mongo
# 2014 added for AN
# Successfully added to mongo
# 2014 added for AZO
# Successfully added to mongo
# 2014 added for AVB
# Successfully added to mongo
# 2014 added for AVY
# Successfully added to mongo
# 2014 added for BHI
# Successfully added to mongo
# 2014 added for BLL
# Successfully added to mongo
# 2014 added for BAC
# Successfully added to mongo
# 2014 added for BK
# Successfully added to mongo
# 2014 added for BCR
# Successfully added to mongo
# 2014 added for BAX
# Successfully added to mongo
# 2014 added for BBT
# Successfully added to mongo
# 2014 added for BDX
# Successfully added to mongo
# 2013 added for BBBY
# Successfully added to mongo
# 2014 added for BRK.B
# Successfully added to mongo
# 2014 added for BBY
# Successfully added to mongo
# 2013 added for BIIB
# Successfully added to mongo
# 2014 added for BLK
# Successfully added to mongo
# 2014 added for HRB
# Successfully added to mongo
# 2014 added for BA
# Successfully added to mongo
# 2014 added for BWA
# Successfully added to mongo
# 2014 added for BXP
# Successfully added to mongo
# 2014 added for BSX
# Successfully added to mongo
# 2014 added for BMY
# Successfully added to mongo
# 343 added for AVGO
# Successfully added to mongo
# 2014 added for BF.B
# Successfully added to mongo
# 2013 added for CHRW
# Successfully added to mongo
# 2013 added for CA
# Successfully added to mongo
# 2014 added for COG
# Successfully added to mongo
# 2014 added for CPB
# Successfully added to mongo
# 2014 added for COF
# Successfully added to mongo
# 2014 added for CAH
# Successfully added to mongo
# 1760 added for CBOE
# Successfully added to mongo
# 2014 added for KMX
# Successfully added to mongo
# 2013 added for CCL
# Successfully added to mongo
# 2014 added for CAT
# Successfully added to mongo
# 2014 added for CBG
# Successfully added to mongo
# 2014 added for CBS
# Successfully added to mongo
# 2013 added for CELG
# Successfully added to mongo
# 2014 added for CNC
# Successfully added to mongo
# 2014 added for CNP
# Successfully added to mongo
# 2014 added for CTL
# Successfully added to mongo
# 2013 added for CERN
# Successfully added to mongo
# 2014 added for CF
# Successfully added to mongo
# 1830 added for SCHW
# Successfully added to mongo
# 268 added for CHTR
# Successfully added to mongo
# 2014 added for CHK
# Successfully added to mongo
# 2014 added for CVX
# Successfully added to mongo
# 2014 added for CMG
# Successfully added to mongo
# 2014 added for CB
# Successfully added to mongo
# 2014 added for CHD
# Successfully added to mongo
# 2014 added for CI
# Successfully added to mongo
# 2014 added for XEC
# Successfully added to mongo
# 2013 added for CINF
# Successfully added to mongo
# 2013 added for CTAS
# Successfully added to mongo
# 2013 added for CSCO
# Successfully added to mongo
# 2014 added for C
# Successfully added to mongo
# 683 added for CFG
# Successfully added to mongo
# 2013 added for CTXS
# Successfully added to mongo
# 2014 added for CLX
# Successfully added to mongo
# 2013 added for CME
# Successfully added to mongo
# 2014 added for CMS
# Successfully added to mongo
# 2014 added for COH
# Successfully added to mongo
# 2014 added for KO
# Successfully added to mongo
# 2013 added for CTSH
# Successfully added to mongo
# 2014 added for CL
# Successfully added to mongo
# 2013 added for CMCSA
# Successfully added to mongo
# 2014 added for CMA
# Successfully added to mongo
# 2014 added for CAG
# Successfully added to mongo
# 2014 added for CXO
# Successfully added to mongo
# 2014 added for COP
# Successfully added to mongo
# 2014 added for ED
# Successfully added to mongo
# 2014 added for STZ
# Successfully added to mongo
# 2014 added for COO
# Successfully added to mongo
# 2014 added for GLW
# Successfully added to mongo
# 2013 added for COST
# Successfully added to mongo
# 1006 added for COTY
# Successfully added to mongo
# 625 added for CCI
# Successfully added to mongo
# 394 added for CSRA
# Successfully added to mongo
# 2012 added for CSX
# Successfully added to mongo
# 2014 added for CMI
# Successfully added to mongo
# 2014 added for CVS
# Successfully added to mongo
# 2014 added for DHI
# Successfully added to mongo
# 2014 added for DHR
# Successfully added to mongo
# 2014 added for DRI
# Successfully added to mongo
# 2014 added for DVA
# Successfully added to mongo
# 2014 added for DE
# Successfully added to mongo
# 1398 added for DLPH
# Successfully added to mongo
# 2014 added for DAL
# Successfully added to mongo
# 2013 added for XRAY
# Successfully added to mongo
# 2014 added for DVN
# Successfully added to mongo
# 2014 added for DLR
# Successfully added to mongo
# 2014 added for DFS
# Successfully added to mongo
# 2013 added for DISCA
# Successfully added to mongo
# 2013 added for DISCK
# Successfully added to mongo
# 2013 added for DISH
# Successfully added to mongo
# 1905 added for DG
# Successfully added to mongo
# 2013 added for DLTR
# Successfully added to mongo
# 2014 added for D
# Successfully added to mongo
# 2014 added for DOV
# Successfully added to mongo
# 2014 added for DOW
# Successfully added to mongo
# 2014 added for DPS
# Successfully added to mongo
# 2014 added for DTE
# Successfully added to mongo
# 2014 added for DD
# Successfully added to mongo
# 2014 added for DUK
# Successfully added to mongo
# 58 added for DXC
# Successfully added to mongo
# 2013 added for ETFC
# Successfully added to mongo
# 2014 added for EMN
# Successfully added to mongo
# 1137 added for ETN
# Successfully added to mongo
# 2013 added for EBAY
# Successfully added to mongo
# 2014 added for ECL
# Successfully added to mongo
# 2014 added for EIX
# Successfully added to mongo
# 2014 added for EW
# Successfully added to mongo
# 2013 added for EA
# Successfully added to mongo
# 2014 added for EMR
# Successfully added to mongo
# 2014 added for ETR
# Successfully added to mongo
# 130 added for EVHC
# Successfully added to mongo
# 2014 added for EOG
# Successfully added to mongo
# 2014 added for EQT
# Successfully added to mongo
# 2014 added for EFX
# Successfully added to mongo
# 599 added for EQIX
# Successfully added to mongo
# 2014 added for EQR
# Successfully added to mongo
# 2014 added for ESS
# Successfully added to mongo
# 2014 added for EL
# Successfully added to mongo
# 2014 added for ES
# Successfully added to mongo
# 2014 added for EXC
# Successfully added to mongo
# 2013 added for EXPE
# Successfully added to mongo
# 2013 added for EXPD
# Successfully added to mongo
# 2013 added for ESRX
# Successfully added to mongo
# 2014 added for EXR
# Successfully added to mongo
# 2014 added for XOM
# Successfully added to mongo
# 2013 added for FFIV
# Successfully added to mongo
# 1274 added for FB
# Successfully added to mongo
# 2013 added for FAST
# Successfully added to mongo
# 2014 added for FRT
# Successfully added to mongo
# 2014 added for FDX
# Successfully added to mongo
# 2014 added for FIS
# Successfully added to mongo
# 2013 added for FITB
# Successfully added to mongo
# 2014 added for FE
# Successfully added to mongo
# 2013 added for FISV
# Successfully added to mongo
# 2013 added for FLIR
# Successfully added to mongo
# 2014 added for FLS
# Successfully added to mongo
# 2014 added for FLR
# Successfully added to mongo
# 2014 added for FMC
# Successfully added to mongo
# 2014 added for FL
# Successfully added to mongo
# 2014 added for F
# Successfully added to mongo
# 250 added for FTV
# Successfully added to mongo
# 1442 added for FBHS
# Successfully added to mongo
# 2014 added for BEN
# Successfully added to mongo
# 2014 added for FCX
# Successfully added to mongo
# 2014 added for GPS
# Successfully added to mongo
# 2012 added for GRMN
# Successfully added to mongo
# 2014 added for IT
# Successfully added to mongo
# 2014 added for GD
# Successfully added to mongo
# 2014 added for GE
# Successfully added to mongo
# 1830 added for GGP
# Successfully added to mongo
# 2014 added for GIS
# Successfully added to mongo
# 1650 added for GM
# Successfully added to mongo
# 2014 added for GPC
# Successfully added to mongo
# 2013 added for GILD
# Successfully added to mongo
# 2014 added for GPN
# Successfully added to mongo
# 2014 added for GS
# Successfully added to mongo
# 2004 added for GT
# Successfully added to mongo
# 2014 added for GWW
# Successfully added to mongo
# 2014 added for HAL
# Successfully added to mongo
# 2014 added for HBI
# Successfully added to mongo
# 2014 added for HOG
# Successfully added to mongo
# 2014 added for HRS
# Successfully added to mongo
# 2014 added for HIG
# Successfully added to mongo
# 2012 added for HAS
# Successfully added to mongo
# 1574 added for HCA
# Successfully added to mongo
# 2014 added for HCP
# Successfully added to mongo
# 2014 added for HP
# Successfully added to mongo
# 2013 added for HSIC
# Successfully added to mongo
# 2014 added for HSY
# Successfully added to mongo
# 2014 added for HES
# Successfully added to mongo
# 414 added for HPE
# Successfully added to mongo
# 2013 added for HOLX
# Successfully added to mongo
# 2014 added for HD
# Successfully added to mongo
# 2014 added for HON
# Successfully added to mongo
# 2014 added for HRL
# Successfully added to mongo
# 2014 added for HST
# Successfully added to mongo
# 2014 added for HPQ
# Successfully added to mongo
# 2014 added for HUM
# Successfully added to mongo
# 2013 added for HBAN
# Successfully added to mongo
# 2013 added for IDXX
# Successfully added to mongo
# 750 added for INFO
# Successfully added to mongo
# 2014 added for ITW
# Successfully added to mongo
# 2013 added for ILMN
# Successfully added to mongo
# 2014 added for IR
# Successfully added to mongo
# 2013 added for INTC
# Successfully added to mongo
# 905 added for ICE
# Successfully added to mongo
# 2014 added for IBM
# Successfully added to mongo
# 2013 added for INCY
# Successfully added to mongo
# 2014 added for IP
# Successfully added to mongo
# 2014 added for IPG
# Successfully added to mongo
# 2014 added for IFF
# Successfully added to mongo
# 2013 added for INTU
# Successfully added to mongo
# 2013 added for ISRG
# Successfully added to mongo
# 2014 added for IVZ
# Successfully added to mongo
# 602 added for IRM
# Successfully added to mongo
# 2014 added for JEC
# Successfully added to mongo
# 2013 added for JBHT
# Successfully added to mongo
# 2014 added for SJM
# Successfully added to mongo
# 2014 added for JNJ
# Successfully added to mongo
# 645 added for JCI
# Successfully added to mongo
# 2014 added for JPM
# Successfully added to mongo
# 2013 added for JNPR
# Successfully added to mongo
# 2014 added for KSU
# Successfully added to mongo
# 2014 added for K
# Successfully added to mongo
# 2014 added for KEY
# Successfully added to mongo
# 2014 added for KMB
# Successfully added to mongo
# 2014 added for KIM
# Successfully added to mongo
# 1592 added for KMI
# Successfully added to mongo
# 2013 added for KLAC
# Successfully added to mongo
# 2014 added for KSS
# Successfully added to mongo
# 488 added for KHC
# Successfully added to mongo
# 2014 added for KR
# Successfully added to mongo
# 2014 added for LB
# Successfully added to mongo
# 2014 added for LLL
# Successfully added to mongo
# 2014 added for LH
# Successfully added to mongo
# 2013 added for LRCX
# Successfully added to mongo
# 2014 added for LEG
# Successfully added to mongo
# 2014 added for LEN
# Successfully added to mongo
# 1418 added for LVLT
# Successfully added to mongo
# 2014 added for LUK
# Successfully added to mongo
# 2014 added for LLY
# Successfully added to mongo
# 2014 added for LNC
# Successfully added to mongo
# 2013 added for LKQ
# Successfully added to mongo
# Error: e
# Error: e
# 2014 added for L
# Successfully added to mongo
# 2014 added for LOW
# Successfully added to mongo
# 1675 added for LYB
# Successfully added to mongo
# 2014 added for MTB
# Successfully added to mongo
# 2014 added for MAC
# Successfully added to mongo
# 2014 added for M
# Successfully added to mongo
# 1004 added for MNK
# Successfully added to mongo
# 2014 added for MRO
# Successfully added to mongo
# 1501 added for MPC
# Successfully added to mongo
# 2013 added for MAR
# Successfully added to mongo
# 2014 added for MMC
# Successfully added to mongo
# 2014 added for MLM
# Successfully added to mongo
# 2014 added for MAS
# Successfully added to mongo
# 2014 added for MA
# Successfully added to mongo
# 1938 added for MAT
# Successfully added to mongo
# 2014 added for MKC
# Successfully added to mongo
# 2014 added for MCD
# Successfully added to mongo
# 2014 added for MCK
# Successfully added to mongo
# 2014 added for MJN
# Successfully added to mongo
# 598 added for MDT
# Successfully added to mongo
# 2013 added for MRK
# Successfully added to mongo
# 2014 added for MET
# Successfully added to mongo
# 2014 added for MTD
# Successfully added to mongo
# 1379 added for KORS
# Successfully added to mongo
# 2013 added for MCHP
# Successfully added to mongo
# 1873 added for MU
# Successfully added to mongo
# 2013 added for MSFT
# Successfully added to mongo
# 2014 added for MAA
# Successfully added to mongo
# 2014 added for MHK
# Successfully added to mongo
# 2014 added for TAP
# Successfully added to mongo
# 1249 added for MDLZ
# Successfully added to mongo
# 2014 added for MON
# Successfully added to mongo
# 502 added for MNST
# Successfully added to mongo
# 2014 added for MCO
# Successfully added to mongo
# 2014 added for MS
# Successfully added to mongo
# 2013 added for MOS
# Successfully added to mongo
# 2014 added for MSI
# Successfully added to mongo
# 2014 added for MUR
# Successfully added to mongo
# 575 added for MYL
# Successfully added to mongo
# 2013 added for NDAQ
# Successfully added to mongo
# 2014 added for NOV
# Successfully added to mongo
# 793 added for NAVI
# Successfully added to mongo
# 2013 added for NTAP
# Successfully added to mongo
# 2013 added for NFLX
# Successfully added to mongo
# Error: e
# Error: e
# 2014 added for NFX
# Successfully added to mongo
# 2014 added for NEM
# Successfully added to mongo
# 1002 added for NWSA
# Successfully added to mongo
# 1002 added for NWS
# Successfully added to mongo
# 2014 added for NEE
# Successfully added to mongo
# 448 added for NLSN
# Successfully added to mongo
# 2014 added for NKE
# Successfully added to mongo
# 2014 added for NI
# Successfully added to mongo
# Error: e
# Error: e
# 2014 added for JWN
# Successfully added to mongo
# 2014 added for NSC
# Successfully added to mongo
# 2012 added for NTRS
# Successfully added to mongo
# 2014 added for NOC
# Successfully added to mongo
# 2014 added for NRG
# Successfully added to mongo
# 2014 added for NUE
# Successfully added to mongo
# 2013 added for NVDA
# Successfully added to mongo
# 2012 added for ORLY
# Successfully added to mongo
# 2014 added for OXY
# Successfully added to mongo
# 2014 added for OMC
# Successfully added to mongo
# 2014 added for OKE
# Successfully added to mongo
# 2014 added for ORCL
# Successfully added to mongo
# 2013 added for PCAR
# Successfully added to mongo
# 2014 added for PH
# Successfully added to mongo
# 2013 added for PDCO
# Successfully added to mongo
# 2013 added for PAYX
# Successfully added to mongo
# 488 added for PYPL
# Successfully added to mongo
# 762 added for PNR
# Successfully added to mongo
# 2013 added for PBCT
# Successfully added to mongo
# 2014 added for PEP
# Successfully added to mongo
# 2014 added for PKI
# Successfully added to mongo
# 874 added for PRGO
# Successfully added to mongo
# 2014 added for PFE
# Successfully added to mongo
# 2014 added for PCG
# Successfully added to mongo
# 2014 added for PM
# Successfully added to mongo
# 1299 added for PSX
# Successfully added to mongo
# 2014 added for PNW
# Successfully added to mongo
# 2014 added for PXD
# Successfully added to mongo
# 2014 added for PNC
# Successfully added to mongo
# 2014 added for RL
# Successfully added to mongo
# 2014 added for PPG
# Successfully added to mongo
# 2014 added for PPL
# Successfully added to mongo
# 2014 added for PX
# Successfully added to mongo
# 2013 added for PCLN
# Successfully added to mongo
# 2014 added for PFG
# Successfully added to mongo
# 2014 added for PG
# Successfully added to mongo
# 2014 added for PGR
# Successfully added to mongo
# 2013 added for PLD
# Successfully added to mongo
# 2014 added for PRU
# Successfully added to mongo
# 2014 added for PEG
# Successfully added to mongo
# 2014 added for PSA
# Successfully added to mongo
# 2014 added for PHM
# Successfully added to mongo
# 2014 added for PVH
# Successfully added to mongo
# 614 added for QRVO
# Successfully added to mongo
# 2014 added for PWR
# Successfully added to mongo
# 2013 added for QCOM
# Successfully added to mongo
# 2014 added for DGX
# Successfully added to mongo
# 2014 added for RRC
# Successfully added to mongo
# 2014 added for RJF
# Successfully added to mongo
# 2014 added for RTN
# Successfully added to mongo
# 2014 added for O
# Successfully added to mongo
# 2014 added for RHT
# Successfully added to mongo
# 2014 added for REG
# Successfully added to mongo
# 2012 added for REGN
# Successfully added to mongo
# 2014 added for RF
# Successfully added to mongo
# 2014 added for RSG
# Successfully added to mongo
# 2014 added for RAI
# Successfully added to mongo
# 2014 added for RHI
# Successfully added to mongo
# 2014 added for ROK
# Successfully added to mongo
# 2014 added for COL
# Successfully added to mongo
# 2014 added for ROP
# Successfully added to mongo
# 2013 added for ROST
# Successfully added to mongo
# 2014 added for RCL
# Successfully added to mongo
# 2014 added for R
# Successfully added to mongo
# 2014 added for CRM
# Successfully added to mongo
# 2014 added for SCG
# Successfully added to mongo
# 2013 added for SLB
# Successfully added to mongo
# 1923 added for SNI
# Successfully added to mongo
# 2012 added for STX
# Successfully added to mongo
# 2014 added for SEE
# Successfully added to mongo
# 2014 added for SRE
# Successfully added to mongo
# 2014 added for SHW
# Successfully added to mongo
# 2014 added for SIG
# Successfully added to mongo
# 2014 added for SPG
# Successfully added to mongo
# 2013 added for SWKS
# Successfully added to mongo
# 2014 added for SLG
# Successfully added to mongo
# 2014 added for SNA
# Successfully added to mongo
# 2014 added for SO
# Successfully added to mongo
# 2014 added for LUV
# Successfully added to mongo
# 2014 added for SPGI
# Successfully added to mongo
# 2014 added for SWK
# Successfully added to mongo
# 2013 added for SPLS
# Successfully added to mongo
# 2013 added for SBUX
# Successfully added to mongo
# 2014 added for STT
# Successfully added to mongo
# 2013 added for SRCL
# Successfully added to mongo
# 2014 added for SYK
# Successfully added to mongo
# 2014 added for STI
# Successfully added to mongo
# 2013 added for SYMC
# Successfully added to mongo
# 721 added for SYF
# Successfully added to mongo
# 2012 added for SNPS
# Successfully added to mongo
# 2014 added for SYY
# Successfully added to mongo
# 2013 added for TROW
# Successfully added to mongo
# 2013 added for TGT
# Successfully added to mongo
# 2014 added for TEL
# Successfully added to mongo
# 101 added for FTI
# Successfully added to mongo
# 2014 added for TDC
# Successfully added to mongo
# 2014 added for TSO
# Successfully added to mongo
# 2012 added for TXN
# Successfully added to mongo
# 2014 added for TXT
# Successfully added to mongo
# 2014 added for TMO
# Successfully added to mongo
# 2014 added for TIF
# Successfully added to mongo
# 2014 added for TWX
# Successfully added to mongo
# 2014 added for TJX
# Successfully added to mongo
# 2014 added for TMK
# Successfully added to mongo
# 2014 added for TSS
# Successfully added to mongo
# 2013 added for TSCO
# Successfully added to mongo
# 2014 added for TDG
# Successfully added to mongo
# 2014 added for RIG
# Successfully added to mongo
# 2014 added for TRV
# Successfully added to mongo
# 1385 added for TRIP
# Successfully added to mongo
# 2013 added for FOXA
# Successfully added to mongo
# 2013 added for FOX
# Successfully added to mongo
# 2014 added for TSN
# Successfully added to mongo
# 2014 added for UDR
# Successfully added to mongo
# 2013 added for ULTA
# Successfully added to mongo
# 2014 added for USB
# Successfully added to mongo
# 305 added for UA
# Successfully added to mongo
# 2014 added for UAA
# Successfully added to mongo
# 2014 added for UNP
# Successfully added to mongo
# 2013 added for UAL
# Successfully added to mongo
# 2014 added for UNH
# Successfully added to mongo
# 2014 added for UPS
# Successfully added to mongo
# 2014 added for URI
# Successfully added to mongo
# 2014 added for UTX
# Successfully added to mongo
# 2014 added for UHS
# Successfully added to mongo
# 2014 added for UNM
# Successfully added to mongo
# 2014 added for VFC
# Successfully added to mongo
# 2014 added for VLO
# Successfully added to mongo
# 2014 added for VAR
# Successfully added to mongo
# 2014 added for VTR
# Successfully added to mongo
# 2013 added for VRSN
# Successfully added to mongo
# 1931 added for VRSK
# Successfully added to mongo
# 2014 added for VZ
# Successfully added to mongo
# 2011 added for VRTX
# Successfully added to mongo
# 2012 added for VIAB
# Successfully added to mongo
# 2014 added for V
# Successfully added to mongo
# 2014 added for VNO
# Successfully added to mongo
# 2014 added for VMC
# Successfully added to mongo
# 2014 added for WMT
# Successfully added to mongo
# 615 added for WBA
# Successfully added to mongo
# 2014 added for DIS
# Successfully added to mongo
# 2014 added for WM
# Successfully added to mongo
# 2014 added for WAT
# Successfully added to mongo
# 2014 added for WEC
# Successfully added to mongo
# 2014 added for WFC
# Successfully added to mongo
# 2014 added for HCN
# Successfully added to mongo
# 2012 added for WDC
# Successfully added to mongo
# 2013 added for WU
# Successfully added to mongo
# 495 added for WRK
# Successfully added to mongo
# 2014 added for WY
# Successfully added to mongo
# 2014 added for WHR
# Successfully added to mongo
# 2013 added for WFM
# Successfully added to mongo
# 2014 added for WMB
# Successfully added to mongo
# 2013 added for WLTW
# Successfully added to mongo
# 2014 added for WYN
# Successfully added to mongo
# 2013 added for WYNN
# Successfully added to mongo
# 2014 added for XEL
# Successfully added to mongo
# 2014 added for XRX
# Successfully added to mongo
# 2013 added for XLNX
# Successfully added to mongo
# 222 added for XL
# Successfully added to mongo
# 1423 added for XYL
# Successfully added to mongo
# 2013 added for YHOO
# Successfully added to mongo
# 2014 added for YUM
# Successfully added to mongo
# 2014 added for ZBH
# Successfully added to mongo
# 2013 added for ZION
# Successfully added to mongo
# 1097 added for ZTS
# Successfully added to mongo
# Done!
# 0:09:07.037935

# %%
print(sp500_collection.count())
print(stocks_collection.count())
# Out:
# 505
# 943687

# %%
sp500_list = [document for document in sp500_collection.find()]
sp500_df = pd.DataFrame(sp500_list)
sp500_df.head()
# Out:
#                         _id    status stock
# 0  593e12b557bbd405c4fb1956  complete   MMM
# 1  593e12b657bbd405c4fb2135  complete   ABT
# 2  593e12b757bbd405c4fb25a3  complete  ABBV
# 3  593e12b857bbd405c4fb2d82  complete   ACN
# 4  593e12ba57bbd405c4fb3560  complete  ATVI

# %%
# Looks like we managed to pull all but 4 stocks
sp500_df[sp500_df['status']=='failed']
# Out:
#                           _id  status stock
# 284  593e13ec57bbd405c4033dab  failed   LMT
# 329  593e141a57bbd405c404748d  failed   NWL
# 338  593e142357bbd405c404a580  failed   NBL

# %%
# Getting ALL data out of a collection
stocks_list = [document for document in stocks_collection.find()]
stocks_df = pd.DataFrame(stocks_list)
stocks_df.sample(5)
# Out:
#         Close       Date   High    Low   Open Stock      Volume  \
# 26112   37.05 2012-09-04  37.48  36.71  36.94     A   3850002.0
# 875770  50.38 2010-07-29  51.58  50.06  51.46   VTR   1588412.0
# 239806  77.28 2011-02-24  79.24  76.51  78.91   COP  13165343.0
# 582215   8.04 2012-02-22   8.24   8.01   8.21    MU  19382392.0
# 465169  35.27 2017-03-17  35.33  35.10  35.31  INTC  30778867.0
#
#                              _id
# 26112   593e12c357bbd405c4fb7785
# 875770  593e14b357bbd405c4087047
# 239806  593e133957bbd405c4febab3
# 582215  593e140557bbd405c403f4f6
# 465169  593e13bf57bbd405c4022b7f

# %%
stocks_df.shape
# Out:
# (943687, 8)

# %% [markdown]
# # NOTE: Can always change this from a classification model to regression model by using Percent_Change as our target instead of Percent_Change_Class

# %% [markdown]
# **We want the <u>PERCENT CHANGE</u> of each stock, so that data is normalized (this is especially important if we are going to make comparisons between stocks)**

# %%
def get_change_in_Close(df):
    list_of_df = []
    for s in df['Stock'].unique():
        try_df = df.loc[df['Stock']==s]
        try_df = try_df.sort(columns='Date')
        try_df['Diff'] = try_df['Close'].diff()
        try_df['Percent_Change'] = (try_df['Close']-try_df['Close'].shift(1))/try_df['Close']
        
        list_of_df.append(try_df)
        
    return list_of_df

# %%
start = datetime.now()

diff_list = get_change_in_Close(stocks_df)

end = datetime.now()
print(end - start)
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel_launcher.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """
# 0:00:53.998178

# %% [markdown]
# **We want to combine these individual stocks into one index (SP500)**<br>
# To do this, we will take the average of the Percent_Change of all stocks for each day.

# %%
sp500_stocks_df = pd.DataFrame()
for i in range(len(diff_list)):
    try_df = pd.DataFrame(diff_list[i])
    sp500_stocks_df = sp500_stocks_df.append(try_df)

# %%
sp500_stocks_df
# Out:
#         Close       Date   High    Low   Open Stock      Volume  \
# 0       60.58 2009-06-11  61.46  60.50  60.57   MMM   3627208.0
# 1       61.00 2009-06-12  61.00  59.91  60.37   MMM   3228967.0
# 2       59.31 2009-06-15  60.40  58.71  60.40   MMM   4231551.0
# 3       58.41 2009-06-16  59.57  58.25  59.41   MMM   3791473.0
# 4       59.04 2009-06-17  59.44  58.59  58.59   MMM   3826144.0
# 5       59.31 2009-06-18  59.95  58.84  58.89   MMM   3194453.0
# 6       59.37 2009-06-19  60.19  58.93  59.48   MMM   5868096.0
# 7       57.47 2009-06-22  59.17  57.42  58.62   MMM   5272874.0
# 8       57.06 2009-06-23  57.74  56.61  57.74   MMM   4161156.0
# 9       57.48 2009-06-24  58.55  57.16  57.46   MMM   4447603.0
# 10      58.90 2009-06-25  59.06  57.10  57.35   MMM   3807829.0
# 11      59.26 2009-06-26  59.47  58.67  58.81   MMM   2989073.0
# 12      59.96 2009-06-29  60.07  58.80  59.36   MMM   3194287.0
# 13      60.10 2009-06-30  60.31  59.59  59.94   MMM   6597178.0
# 14      60.74 2009-07-01  61.29  60.09  60.31   MMM   3839823.0
# 15      60.25 2009-07-02  60.74  59.68  59.90   MMM   5583065.0
# 16      60.67 2009-07-06  60.78  59.63  59.87   MMM   5791564.0
# 17      58.76 2009-07-07  61.30  58.69  61.09   MMM   7289351.0
# 18      59.02 2009-07-08  59.25  57.81  58.87   MMM   6101447.0
# 19      59.09 2009-07-09  59.47  58.75  59.28   MMM   3164373.0
# 20      59.79 2009-07-10  59.92  58.46  58.68   MMM   3911496.0
# 21      60.49 2009-07-13  60.53  59.30  59.83   MMM   4041592.0
# 22      60.63 2009-07-14  61.00  60.00  60.47   MMM   3538154.0
# 23      62.00 2009-07-15  62.15  60.94  61.20   MMM   5023426.0
# 24      63.40 2009-07-16  63.54  61.82  61.91   MMM   4128933.0
# 25      62.92 2009-07-17  63.48  62.16  63.14   MMM   4580673.0
# 26      63.84 2009-07-20  63.95  63.08  63.62   MMM   3824845.0
# 27      64.20 2009-07-21  64.74  63.36  64.44   MMM   5029934.0
# 28      64.67 2009-07-22  64.89  64.05  64.26   MMM   4162711.0
# 29      69.43 2009-07-23  69.72  66.35  66.58   MMM  10779177.0
# ...       ...        ...    ...    ...    ...   ...         ...
# 943657  56.11 2017-04-28  56.62  56.08  56.46   ZTS   3341793.0
# 943658  56.28 2017-05-01  56.56  56.03  56.14   ZTS   3607817.0
# 943659  56.47 2017-05-02  56.53  55.89  56.29   ZTS   3728559.0
# 943660  55.59 2017-05-03  56.40  55.50  56.09   ZTS   5795937.0
# 943661  58.87 2017-05-04  59.60  55.48  55.48   ZTS   6923157.0
# 943662  59.47 2017-05-05  59.61  58.48  58.76   ZTS   6896027.0
# 943663  58.81 2017-05-08  59.74  58.30  59.39   ZTS   3160708.0
# 943664  59.43 2017-05-09  59.69  58.55  58.80   ZTS   3130507.0
# 943665  59.90 2017-05-10  60.12  58.99  58.99   ZTS   4052762.0
# 943666  59.72 2017-05-11  59.89  59.25  59.68   ZTS   3175456.0
# 943667  59.88 2017-05-12  60.19  59.57  60.03   ZTS   3425146.0
# 943668  60.00 2017-05-15  60.07  59.56  59.77   ZTS   2319379.0
# 943669  60.33 2017-05-16  60.38  59.90  60.24   ZTS   1816297.0
# 943670  59.73 2017-05-17  60.19  59.69  59.86   ZTS   2397563.0
# 943671  59.91 2017-05-18  60.29  59.61  59.73   ZTS   1583662.0
# 943672  60.31 2017-05-19  60.61  59.94  59.98   ZTS   2567745.0
# 943673  60.31 2017-05-22  60.88  60.28  60.39   ZTS   3117309.0
# 943674  61.43 2017-05-23  61.46  60.50  60.50   ZTS   3330549.0
# 943675  62.30 2017-05-24  62.48  61.39  61.43   ZTS   3869148.0
# 943676  62.58 2017-05-25  62.64  62.17  62.56   ZTS   2864917.0
# 943677  62.61 2017-05-26  63.11  62.38  62.78   ZTS   1985460.0
# 943678  62.26 2017-05-30  62.70  61.86  62.45   ZTS   2884394.0
# 943679  62.28 2017-05-31  62.70  62.10  62.58   ZTS   3789807.0
# 943680  62.64 2017-06-01  62.64  61.99  62.45   ZTS   3112530.0
# 943681  62.50 2017-06-02  63.30  62.39  62.78   ZTS   4110099.0
# 943682  62.67 2017-06-05  62.78  62.15  62.42   ZTS   3364563.0
# 943683  62.98 2017-06-06  63.08  62.49  62.50   ZTS   2420424.0
# 943684  63.26 2017-06-07  63.42  62.85  62.93   ZTS   1904655.0
# 943685  62.58 2017-06-08  63.49  62.46  63.41   ZTS   3201991.0
# 943686  62.59 2017-06-09  63.10  62.37  62.49   ZTS   2021775.0
#
#                              _id  Diff  Percent_Change
# 0       593e12b557bbd405c4fb1178   NaN             NaN
# 1       593e12b557bbd405c4fb1179  0.42        0.006885
# 2       593e12b557bbd405c4fb117a -1.69       -0.028494
# 3       593e12b557bbd405c4fb117b -0.90       -0.015408
# 4       593e12b557bbd405c4fb117c  0.63        0.010671
# 5       593e12b557bbd405c4fb117d  0.27        0.004552
# 6       593e12b557bbd405c4fb117e  0.06        0.001011
# 7       593e12b557bbd405c4fb117f -1.90       -0.033061
# 8       593e12b557bbd405c4fb1180 -0.41       -0.007185
# 9       593e12b557bbd405c4fb1181  0.42        0.007307
# 10      593e12b557bbd405c4fb1182  1.42        0.024109
# 11      593e12b557bbd405c4fb1183  0.36        0.006075
# 12      593e12b557bbd405c4fb1184  0.70        0.011674
# 13      593e12b557bbd405c4fb1185  0.14        0.002329
# 14      593e12b557bbd405c4fb1186  0.64        0.010537
# 15      593e12b557bbd405c4fb1187 -0.49       -0.008133
# 16      593e12b557bbd405c4fb1188  0.42        0.006923
# 17      593e12b557bbd405c4fb1189 -1.91       -0.032505
# 18      593e12b557bbd405c4fb118a  0.26        0.004405
# 19      593e12b557bbd405c4fb118b  0.07        0.001185
# 20      593e12b557bbd405c4fb118c  0.70        0.011708
# 21      593e12b557bbd405c4fb118d  0.70        0.011572
# 22      593e12b557bbd405c4fb118e  0.14        0.002309
# 23      593e12b557bbd405c4fb118f  1.37        0.022097
# 24      593e12b557bbd405c4fb1190  1.40        0.022082
# 25      593e12b557bbd405c4fb1191 -0.48       -0.007629
# 26      593e12b557bbd405c4fb1192  0.92        0.014411
# 27      593e12b557bbd405c4fb1193  0.36        0.005607
# 28      593e12b557bbd405c4fb1194  0.47        0.007268
# 29      593e12b557bbd405c4fb1195  4.76        0.068558
# ...                          ...   ...             ...
# 943657  593e14d757bbd405c409799a -0.35       -0.006238
# 943658  593e14d757bbd405c409799b  0.17        0.003021
# 943659  593e14d757bbd405c409799c  0.19        0.003365
# 943660  593e14d757bbd405c409799d -0.88       -0.015830
# 943661  593e14d757bbd405c409799e  3.28        0.055716
# 943662  593e14d757bbd405c409799f  0.60        0.010089
# 943663  593e14d757bbd405c40979a0 -0.66       -0.011223
# 943664  593e14d757bbd405c40979a1  0.62        0.010432
# 943665  593e14d757bbd405c40979a2  0.47        0.007846
# 943666  593e14d757bbd405c40979a3 -0.18       -0.003014
# 943667  593e14d757bbd405c40979a4  0.16        0.002672
# 943668  593e14d757bbd405c40979a5  0.12        0.002000
# 943669  593e14d757bbd405c40979a6  0.33        0.005470
# 943670  593e14d757bbd405c40979a7 -0.60       -0.010045
# 943671  593e14d757bbd405c40979a8  0.18        0.003005
# 943672  593e14d757bbd405c40979a9  0.40        0.006632
# 943673  593e14d757bbd405c40979aa  0.00        0.000000
# 943674  593e14d757bbd405c40979ab  1.12        0.018232
# 943675  593e14d757bbd405c40979ac  0.87        0.013965
# 943676  593e14d757bbd405c40979ad  0.28        0.004474
# 943677  593e14d757bbd405c40979ae  0.03        0.000479
# 943678  593e14d757bbd405c40979af -0.35       -0.005622
# 943679  593e14d757bbd405c40979b0  0.02        0.000321
# 943680  593e14d757bbd405c40979b1  0.36        0.005747
# 943681  593e14d757bbd405c40979b2 -0.14       -0.002240
# 943682  593e14d757bbd405c40979b3  0.17        0.002713
# 943683  593e14d757bbd405c40979b4  0.31        0.004922
# 943684  593e14d757bbd405c40979b5  0.28        0.004426
# 943685  593e14d757bbd405c40979b6 -0.68       -0.010866
# 943686  593e14d757bbd405c40979b7  0.01        0.000160
#
# [943687 rows x 10 columns]

# %%
# Download data and fact-check results in Excel to see if calculations were done correctly
sp500_stocks_df.to_csv('../Analyzing_Unstructured_Data_for_Finance/data/3.2.sp500_stocks.csv')

# %%
sp500_stocks_df = sp500_stocks_df.pivot_table(columns='Date').T

# %%
sp500_stocks_df.shape
# Out:
# (2014, 7)

# %% [markdown]
# # NOTE: Might want to consider tweaking the threshold
# (e.g. what percent change can my model detect?)

# %%
# Look at the distribution of Percent_Change to determine what threshold to use
print('min: ', sp500_stocks_df['Percent_Change'].min())
print('max: ', sp500_stocks_df['Percent_Change'].max())
print('mean: ', sp500_stocks_df['Percent_Change'].mean())

print('mode: ', "{0:.10f}".format(round(sp500_stocks_df['Percent_Change'],2).mode()[0]))
print('mode: ', "{0:.10f}".format(round(sp500_stocks_df['Percent_Change'],5).mode()[0]))
# Out:
# min:  -0.0815379205331
# max:  0.051627944931
# mean:  0.000329585358775
# mode:  0.0000000000
# mode:  -0.0011800000

# %%
# Make threshold .5% (for percent change in daily Close price)
def make_binary(data):
    data_list = []
    for d in data:
        if round(d,3) < 0.005:
            data_list.append('down')
        elif round(d,3) == 0.005:
            data_list.append('neutral')
        elif round(d,3) > 0.005:
            data_list.append('up')
        else:
            data_list.append(None)
    return data_list

# %%
sp500_stocks_df['Percent_Change_Class'] = make_binary(sp500_stocks_df['Percent_Change'])

# %%
sp500_stocks_df['Percent_Change_Class'].value_counts()
# Out:
# down       1391
# up          536
# neutral      86
# Name: Percent_Change_Class, dtype: int64

# %%
sp500_stocks_df = sp500_stocks_df.reset_index()

# %%
sp500_stocks_df['Date'] = sp500_stocks_df['Date'].dt.date

# %%
sp500_stocks_df.shape
# Out:
# (2014, 9)

# %%
sp500_stocks_df.sample(5)
# Out:
#             Date      Close      Diff       High        Low       Open  \
# 125   2009-12-08  38.845656 -0.314072  39.299774  38.451606  38.934887
# 1695  2016-03-07  81.530324  0.043907  82.207794  80.293198  81.016579
# 604   2011-11-01  48.009207 -1.360815  48.961718  47.288436  47.880617
# 1170  2014-02-04  72.040127  0.673425  72.634989  71.027928  71.758858
# 624   2011-11-30  49.053560  2.041626  49.292665  47.977885  48.388987
#
#       Percent_Change        Volume Percent_Change_Class
# 125        -0.009200  7.592391e+06                 down
# 1695        0.003840  5.020520e+06                 down
# 604        -0.030821  9.170421e+06                 down
# 1170        0.008712  5.861444e+06                   up
# 624         0.043303  9.073965e+06                   up

# %%
pd.to_pickle(sp500_stocks_df, '../Analyzing_Unstructured_Data_for_Finance/data/3.2.sp500_stocks_df.pickle')
