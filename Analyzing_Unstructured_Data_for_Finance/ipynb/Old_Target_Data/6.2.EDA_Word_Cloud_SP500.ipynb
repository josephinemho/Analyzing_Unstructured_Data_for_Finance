# %% [markdown]
# # Part 6 -- EDA (WordCloud) on SP500
#
# Let's do some Exploratory Data Analysis using WordCloud.

# %% [markdown]
# **Load lib codes**

# %%
from os import chdir
chdir('/home/jovyan/work/Portfolio/Analyzing_Unstructured_Data_for_Finance/')

from lib import *
# suppress_warnings()

# %%
combined_df = pd.read_pickle('../Analyzing_Unstructured_Data_for_Finance/data/4.2.combined_df_SP500.pickle')

# %% [markdown]
# ### Explore with WordCloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
# Edit stop words to focus more on nuances and take away the noise
stopwords = set(STOPWORDS)
stopwords.add('rt')
stopwords.add('amp')

# %%
up_wc = WordCloud(width=1600, height=800, background_color='white', relative_scaling=1, stopwords=stopwords, colormap='winter').generate(' '.join(i for i in combined_df['cleaned_text'][combined_df[0]=='up']))

plt.figure(figsize=(20,10))
plt.imshow(up_wc)
plt.axis("off")
plt.show()

# %%
neutral_wc = WordCloud(width=1600, height=800, background_color='white', relative_scaling=1, stopwords=stopwords, colormap='copper').generate(' '.join(i for i in combined_df['cleaned_text'][combined_df[0]=='neutral']))

plt.figure(figsize=(20,10))
plt.imshow(neutral_wc)
plt.axis("off")
plt.show()

# %%
down_wc = WordCloud(width=1600, height=800, background_color='white', relative_scaling=1, stopwords=stopwords, colormap='autumn').generate(' '.join(i for i in combined_df['cleaned_text'][combined_df[0]=='down']))

plt.figure(figsize=(20,10))
plt.imshow(down_wc)
plt.axis("off")
plt.show()

# %% [markdown]
# ** Finding meaning in tweets might be about nuance (since there's so much noise). Let's try taking away all the features that contribute the most to our variance.**

# %%
# Edit stop words to focus more on nuances and take away the noise
stopwords = set(STOPWORDS)
stopwords.add('rt')
stopwords.add('amp')
stopwords.add('re')
stopwords.add('trump')
stopwords.add('will')
stopwords.add('new')
stopwords.add('say')
stopwords.add('stock')
stopwords.add('today')
stopwords.add('one')
stopwords.add('says')
stopwords.add('via')
stopwords.add('year')
stopwords.add('us')
stopwords.add('people')
stopwords.add('now')
stopwords.add('time')
stopwords.add('market')
stopwords.add('stocks')
stopwords.add('may')
stopwords.add('make')
stopwords.add('big')
stopwords.add('right')
stopwords.add('business')
stopwords.add('great')
stopwords.add('thank')
stopwords.add('take')
stopwords.add('investor')
stopwords.add('investors')

# %%
up_wc = WordCloud(width=1600, height=800, background_color='white', relative_scaling=1, stopwords=stopwords, colormap='winter').generate(' '.join(i for i in combined_df['cleaned_text'][combined_df[0]=='up']))
plt.figure(figsize=(20,10))
plt.imshow(up_wc)
plt.axis("off")
plt.show()

# %%
neutral_wc = WordCloud(width=1600, height=800, background_color='white', relative_scaling=1, stopwords=stopwords, colormap='copper').generate(' '.join(i for i in combined_df['cleaned_text'][combined_df[0]=='neutral']))

plt.figure(figsize=(20,10))
plt.imshow(neutral_wc)
plt.axis("off")
plt.show()

# %%
down_wc = WordCloud(width=1600, height=800, background_color='white', relative_scaling=1, stopwords=stopwords, colormap='autumn').generate(' '.join(i for i in combined_df['cleaned_text'][combined_df[0]=='down']))

plt.figure(figsize=(20,10))
plt.imshow(down_wc)
plt.axis("off")
plt.show()
