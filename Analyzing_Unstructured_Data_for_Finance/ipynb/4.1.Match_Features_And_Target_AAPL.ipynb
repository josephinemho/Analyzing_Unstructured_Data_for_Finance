# %% [markdown]
# # Part 4 -- Combine Features and Target (AAPL)
#
# Since our feature data (Tweets) and target data (stocks) are pulled from different sources and have different numbers of rows and columns, we will need to do some cleaning to make sure our X's and y's share the same number of rows. This is important for when we feed our data into models.

# %% [markdown]
# **Load lib codes**

# %%
from os import chdir
chdir('/home/jovyan/work/Portfolio/Analyzing_Unstructured_Data_for_Finance/')

from lib import *
# suppress_warnings()

# %%
AAPL_df = pd.read_pickle('../Analyzing_Unstructured_Data_for_Finance/data/3.1.AAPL_df.pickle')

# %%
tweets_df = pd.read_pickle('../Analyzing_Unstructured_Data_for_Finance/data/2.tweets_df.pickle')

# %%
AAPL_df.shape
# Out:
# (2013, 9)

# %%
tweets_df.shape
# Out:
# (94856, 6)

# %% [markdown]
# **Do some checks to see if everything matches correctly before merging the dataframes**

# %%
AAPL_df[2000:2005]
# Out:
#             Date    Open    High     Low   Close    Volume  Diff  \
# 2000  2017-05-23  154.90  154.90  153.31  153.80  19918871 -0.19
# 2001  2017-05-24  153.84  154.17  152.67  153.34  19219154 -0.46
# 2002  2017-05-25  153.73  154.35  153.03  153.87  19235598  0.53
# 2003  2017-05-26  154.00  154.24  153.31  153.61  21927637 -0.26
# 2004  2017-05-30  153.42  154.43  153.33  153.67  20126851  0.06
#
#       Percent_Change Percent_Change_Class
# 2000       -0.001235                 down
# 2001       -0.003000                 down
# 2002        0.003444                 down
# 2003       -0.001693                 down
# 2004        0.000390                 down

# %%
tweets_df[:5]
# Out:
#                         _id  \
# 0  593deb7057bbd4047664223e
# 1  593deb7057bbd4047664223f
# 2  593deb7057bbd40476642240
# 3  593deb7057bbd40476642241
# 4  593deb7057bbd40476642242
#
#                                                 text           timestamp  \
# 0  On this National Gun Violence Awareness Day, l... 2017-06-02 17:35:54
# 1  Forever grateful for the service and sacrifice... 2017-05-29 13:09:16
# 2  Good to see my friend Prince Harry in London t... 2017-05-27 13:15:25
# 3  Through faith, love, and resolve the character... 2017-05-25 14:13:35
# 4  Our hearts go out to those killed and wounded ... 2017-05-23 16:56:14
#
#       username        Date                                       cleaned_text
# 0  BarackObama  2017-06-02  on this national gun violence awareness day le...
# 1  BarackObama  2017-05-29  forever grateful for the service and sacrifice...
# 2  BarackObama  2017-05-27  good to see my friend prince harry in london t...
# 3  BarackObama  2017-05-25  through faith love and resolve the character o...
# 4  BarackObama  2017-05-23  our hearts go out to those killed and wounded ...

# %%
tweets_df['Date'][3]==AAPL_df['Date'][2002]
# Out:
# True

# %%
AAPL_df[AAPL_df['Percent_Change_Class']=='neutral']
# Out:
#             Date    Open    High     Low   Close     Volume  Diff  \
# 18    2009-07-08   19.42   19.72   19.20   19.60  143982048  0.26
# 26    2009-07-20   21.90   22.15   21.56   21.84  183881187  0.16
# 29    2009-07-23   22.38   22.63   22.22   22.55  131740378  0.16
# 30    2009-07-24   22.42   22.86   22.36   22.86  109589914  0.31
# 40    2009-08-07   23.64   23.80   23.54   23.64   96870928  0.22
# 49    2009-08-20   23.57   23.82   23.52   23.76   85549730  0.25
# 54    2009-08-27   24.11   24.22   23.55   24.21  112294826  0.29
# 59    2009-09-03   23.78   23.87   23.57   23.79   73525711  0.19
# 1980  2017-04-25  143.91  144.90  143.87  144.53   18871501  0.89
# 1985  2017-05-02  147.54  148.09  146.84  147.51   45352194  0.93
# 1990  2017-05-09  153.87  154.88  153.45  153.99   39130363  0.98
# 1993  2017-05-12  154.70  156.42  154.67  156.10   32527017  2.15
# 1999  2017-05-22  154.00  154.58  152.91  153.99   22966437  0.93
# 2007  2017-06-02  153.58  155.45  152.89  155.45   27770715  2.27
# 2010  2017-06-07  155.02  155.98  154.48  155.37   21069647  0.92
#
#       Percent_Change Percent_Change_Class
# 18          0.013265              neutral
# 26          0.007326              neutral
# 29          0.007095              neutral
# 30          0.013561              neutral
# 40          0.009306              neutral
# 49          0.010522              neutral
# 54          0.011979              neutral
# 59          0.007987              neutral
# 61          0.014980              neutral
# 63          0.008114              neutral
# 65          0.009267              neutral
# 66          0.007994              neutral
# 68          0.014416              neutral
# 72          0.005660              neutral
# 80          0.006022              neutral
# 84          0.006248              neutral
# 87          0.006586              neutral
# 90          0.009587              neutral
# 102         0.011005              neutral
# 106         0.007586              neutral
# 109         0.011982              neutral
# 110         0.010501              neutral
# 129         0.011727              neutral
# 134         0.014124              neutral
# 135         0.010482              neutral
# 136         0.008660              neutral
# 138         0.012239              neutral
# 140         0.011909              neutral
# 146         0.006605              neutral
# 149         0.013958              neutral
# ...              ...                  ...
# 1886        0.009727              neutral
# 1887        0.009722              neutral
# 1892        0.005439              neutral
# 1894        0.005744              neutral
# 1899        0.006311              neutral
# 1905        0.005060              neutral
# 1906        0.011025              neutral
# 1907        0.009076              neutral
# 1909        0.005344              neutral
# 1912        0.008000              neutral
# 1926        0.009287              neutral
# 1927        0.009428              neutral
# 1931        0.008778              neutral
# 1932        0.012813              neutral
# 1936        0.007169              neutral
# 1944        0.005866              neutral
# 1952        0.010466              neutral
# 1955        0.010392              neutral
# 1957        0.011172              neutral
# 1966        0.007391              neutral
# 1974        0.005500              neutral
# 1977        0.012356              neutral
# 1979        0.009538              neutral
# 1980        0.006158              neutral
# 1985        0.006305              neutral
# 1990        0.006364              neutral
# 1993        0.013773              neutral
# 1999        0.006039              neutral
# 2007        0.014603              neutral
# 2010        0.005921              neutral
#
# [447 rows x 9 columns]

# %%
AAPL_df['Percent_Change_Class'].loc[AAPL_df['Date']==dt.date(2009, 7, 8)].values
# Out:
# array(['neutral'], dtype=object)

# %%
def match_dates_and_get_stock_change(features_df, target_df):
    change = []

    for i in features_df['Date']:
        try:
            if i in list(target_df['Date']):
                change.append(target_df['Percent_Change_Class'].loc[target_df['Date']==i].values)
            elif i not in list(target_df['Date']):
                change.append('x')
                pass
        except Exception as e:
            print('Error:', e)
            
    return pd.DataFrame(change)

# %%
start = datetime.now()

change_df = match_dates_and_get_stock_change(tweets_df, AAPL_df)

end = datetime.now()
print(end - start)
# Out:
# 0:01:03.680343

# %%
change_df[0].value_counts()
# Out:
# down       54061
# x          17573
# neutral    16515
# up          6707
# Name: 0, dtype: int64

# %%
54061+17573+16515+6707
# Out:
# 94856

# %% [markdown]
# **Now, we have our X's and y's**<br>
# Our <u>Features</u> == Tweets (\_id, text, timestamp, username, cleaned_text, Date)<br>
# Our <u>Target</u> == change in stock prices (up/down/neutral)<br>
#
# They have the same number of rows and are in the same order, so our X and Y's are ready! Now, we just need to drop the rows where our X's and y's don't have a Date in common.

# %% [markdown]
# **Merge & drop rows where there's no stock data for Tweets**

# %%
combined_df_nodrop = tweets_df.merge(change_df, left_index=True, right_index=True)

# %%
combined_df_nodrop.head(5)
# Out:
#                         _id  \
# 0  593deb7057bbd4047664223e
# 1  593deb7057bbd4047664223f
# 2  593deb7057bbd40476642240
# 3  593deb7057bbd40476642241
# 4  593deb7057bbd40476642242
#
#                                                 text           timestamp  \
# 0  On this National Gun Violence Awareness Day, l... 2017-06-02 17:35:54
# 1  Forever grateful for the service and sacrifice... 2017-05-29 13:09:16
# 2  Good to see my friend Prince Harry in London t... 2017-05-27 13:15:25
# 3  Through faith, love, and resolve the character... 2017-05-25 14:13:35
# 4  Our hearts go out to those killed and wounded ... 2017-05-23 16:56:14
#
#       username        Date                                       cleaned_text  \
# 0  BarackObama  2017-06-02  on this national gun violence awareness day le...
# 1  BarackObama  2017-05-29  forever grateful for the service and sacrifice...
# 2  BarackObama  2017-05-27  good to see my friend prince harry in london t...
# 3  BarackObama  2017-05-25  through faith love and resolve the character o...
# 4  BarackObama  2017-05-23  our hearts go out to those killed and wounded ...
#
#          0
# 0  neutral
# 1        x
# 2        x
# 3     down
# 4     down

# %%
combined_df = combined_df_nodrop[combined_df_nodrop[0]!='x']

# %%
combined_df.head(5)
# Out:
#                         _id  \
# 0  593deb7057bbd4047664223e
# 3  593deb7057bbd40476642241
# 4  593deb7057bbd40476642242
# 5  593deb7057bbd40476642243
# 7  593deb7057bbd40476642245
#
#                                                 text           timestamp  \
# 0  On this National Gun Violence Awareness Day, l... 2017-06-02 17:35:54
# 3  Through faith, love, and resolve the character... 2017-05-25 14:13:35
# 4  Our hearts go out to those killed and wounded ... 2017-05-23 16:56:14
# 5  Excited to hear from Sierra, Imani, Filiz, and... 2017-05-22 21:16:23
# 7  We're rolling up our sleeves again, back where... 2017-05-03 19:42:16
#
#       username        Date                                       cleaned_text  \
# 0  BarackObama  2017-06-02  on this national gun violence awareness day le...
# 3  BarackObama  2017-05-25  through faith love and resolve the character o...
# 4  BarackObama  2017-05-23  our hearts go out to those killed and wounded ...
# 5  BarackObama  2017-05-22  excited to hear from sierra imani filiz and be...
# 7  BarackObama  2017-05-03  we re rolling up our sleeves again back where ...
#
#          0
# 0  neutral
# 3     down
# 4     down
# 5  neutral
# 7     down

# %%
pd.to_pickle(combined_df, '../Analyzing_Unstructured_Data_for_Finance/data/4.1.combined_df_AAPL.pickle')

# %% [markdown]
# **Now split the data into X's and y's - our features and target**

# %%
X = combined_df.drop(0, axis=1)
y = combined_df[0]

# %%
print(X.shape)
print(y.shape)
# Out:
# (77283, 6)
# (77283,)

# %%
77283.0/94856.0
# We kept 81% of original tweets (after dropping ones that don't match)
# Out:
# 0.8147402378341908

# %%
pd.to_pickle(X, '../Analyzing_Unstructured_Data_for_Finance/data/4.1.X.pickle')

# %%
pd.to_pickle(y, '../Analyzing_Unstructured_Data_for_Finance/data/4.1.y_AAPL.pickle')

# %%
combined_df[0].value_counts()
# Out:
# down       54061
# neutral    16515
# up          6707
# Name: 0, dtype: int64
